# %% [markdown]
# <a href="https://colab.research.google.com/github/juanjararPYBM/ibm-data-science-portfolio/blob/main/proyecto_medico/Master_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# MÓDULO INTEGRAL: MASTER INDEX (V5 - PALETA DE ALTO CONTRASTE)
# =============================================================================
from IPython.display import HTML, display

urls = {
    "github": "https://github.com",
    "fase1": "#", "fase2": "#", "fase3": "#", "fase4": "#", "fase5": "#", "fase6": "#"
}

# -----------------------------------------------------------------------------
# MÓDULO 0: ESTILOS CSS (DIFERENCIACIÓN DE FASE 6 + SEMÁFOROS)
# -----------------------------------------------------------------------------
css_styles = f"""
<style>
    @import url('https://fonts.googleapis.com');

    :root {{
        --primary: #2e6171;    --f1-blue: #007bff;
        --f2-purple: #a100ff;  --f3-orange: #ff7b00;
        --f4-red: #ff2a00;     --f5-green: #27ae60;
        --f6-dark: #2c3e50;    --glass-bg: #f8f9fa;
    }}

    .master-container {{
        font-family: 'Inter', sans-serif; padding: 35px; background: white;
        border-radius: 15px; border: 1px solid #eee; max-width: 950px; margin: auto;
    }}

    /* HEADER: Botones Compactos */
    .reveal-group {{ display: flex; gap: 8px; margin-bottom: 25px; }}
    .reveal-btn {{
        padding: 6px 15px; border-radius: 8px; background: var(--glass-bg);
        border: 1px solid #e1e4e8; color: #455a64; font-size: 0.8em; cursor: pointer;
        transition: all 0.5s ease; display: inline-flex; align-items: center;
        overflow: hidden; max-width: 100px; white-space: nowrap; font-weight: 600; text-decoration: none;
    }}
    .reveal-btn strong {{ font-family: 'Montserrat', sans-serif; margin-right: 10px; color: var(--primary); }}
    .reveal-btn:hover {{ max-width: 500px; background: var(--primary) !important; color: white !important; border-color: var(--primary); }}
    .reveal-btn:hover strong {{ color: white !important; }}
    .reveal-btn .content {{ opacity: 0; transition: 0.4s; }}
    .reveal-btn:hover .content {{ opacity: 1; }}

    /* ROLES: Efecto 1 y 4 */
    .role-container {{ display: flex; flex-direction: column; gap: 8px; margin-top: 15px; }}
    .role-row {{
        display: inline-flex; align-items: center; gap: 12px; padding: 6px 12px;
        border-radius: 6px; cursor: default; opacity: 0.65;
        transition: all 0.4s cubic-bezier(0.175, 0.885, 0.32, 1.275);
        align-self: flex-start;
    }}
    .role-row:hover {{ opacity: 1; transform: translateY(-3px); box-shadow: 0 6px 12px rgba(0,0,0,0.06); background: white; }}
    .role-label {{ padding: 5px 12px; font-weight: 700; font-size: 0.65em; text-transform: uppercase; border-radius: 2px; min-width: 110px; text-align: center; }}
    .label-client {{ background: #ebf5fb; border-left: 6px solid var(--f1-blue); color: var(--f1-blue); }}
    .label-scientist {{ background: #fdf2e9; border-left: 8px solid var(--f3-orange); color: var(--f3-orange); }}

    /* ÍNDICE: Título Centrado */
    .index-title {{
        color: var(--primary); font-family: 'Montserrat', sans-serif; font-size: 0.85em;
        text-transform: uppercase; margin: 40px 0 20px 0; letter-spacing: 2px; text-align: center;
        display: flex; align-items: center; justify-content: center; gap: 15px; font-weight: 800;
    }}
    .index-title::before, .index-title::after {{ content: ""; flex: 1; height: 1px; background: #eee; }}

    /* FASES: Lista con Semáforo */
    .phase-list {{ display: flex; flex-direction: column; gap: 10px; }}
    .phase-item {{
        display: flex; align-items: center; padding: 14px 22px; border-radius: 12px;
        border: 1px solid #f2f2f2; text-decoration: none; color: #555; background: #fff;
        opacity: 0.75; transition: all 0.3s cubic-bezier(0.175, 0.885, 0.32, 1.275);
        justify-content: space-between;
    }}

    .phase-item strong {{ font-family: 'Montserrat', sans-serif; font-size: 0.9em; min-width: 85px; transition: 0.3s; }}
    .phase-info {{ display: flex; align-items: center; flex-grow: 1; }}
    .phase-desc {{ font-size: 0.85em; margin-left: 20px; color: #777; border-left: 1px solid #f0f0f0; padding-left: 15px; transition: 0.3s; flex-grow: 1; }}

    /* SEMÁFORO (Status Dot) */
    .status-dot {{ width: 8px; height: 8px; border-radius: 50%; margin-left: 15px; transition: all 0.3s ease; border: 1px solid rgba(0,0,0,0.1); }}
    .dot-green {{ background-color: #2ecc71; box-shadow: 0 0 5px rgba(46, 204, 113, 0.2); }}
    .dot-yellow {{ background-color: #f1c40f; box-shadow: 0 0 5px rgba(241, 196, 15, 0.2); }}
    .dot-red {{ background-color: #e74c3c; box-shadow: 0 0 5px rgba(231, 76, 60, 0.2); }}

    /* Hover Fases: Inversión de Color + Elevación + Brillo de Semáforo */
    .phase-item:hover {{ opacity: 1; transform: translateY(-5px); color: white !important; }}
    .phase-item:hover .phase-desc {{ color: rgba(255,255,255,0.9); border-left-color: rgba(255,255,255,0.3); }}
    .phase-item:hover strong {{ color: white !important; }}
    .phase-item:hover .status-dot {{ border-color: white; transform: scale(1.3); box-shadow: 0 0 15px white; }}

    /* Colores por Fase (Hover) */
    .p1:hover {{ background-color: var(--f1-blue); border-color: var(--f1-blue); box-shadow: 0 10px 25px rgba(0, 123, 255, 0.3); }}
    .p2:hover {{ background-color: var(--f2-purple); border-color: var(--f2-purple); box-shadow: 0 10px 25px rgba(161, 0, 255, 0.3); }}
    .p3:hover {{ background-color: var(--f3-orange); border-color: var(--f3-orange); box-shadow: 0 10px 25px rgba(255, 123, 0, 0.3); }}
    .p4:hover {{ background-color: var(--f4-red); border-color: var(--f4-red); box-shadow: 0 10px 25px rgba(255, 42, 0, 0.3); }}
    .p5:hover {{ background-color: var(--f5-green); border-color: var(--f5-green); box-shadow: 0 10px 25px rgba(39, 174, 96, 0.3); }}
    .p6:hover {{ background-color: var(--f6-dark); border-color: var(--f6-dark); box-shadow: 0 10px 25px rgba(44, 62, 80, 0.3); }}
</style>
"""

# -----------------------------------------------------------------------------
# MÓDULOS DE COMPONENTES
# -----------------------------------------------------------------------------
header_component = f"""
<div class="master-container">
    <h1 style="color:var(--primary); font-family:'Montserrat',sans-serif; font-weight:800; font-size:2.2em; margin-bottom:20px; letter-spacing:-1.2px;">
        IBM Data Science: Proyecto Final
    </h1>

    <div class="reveal-group">
        <div class="reveal-btn"><strong>AUTOR</strong> <span class="content">Juan Pablo Jaramillo Ormaza</span></div>
        <div class="reveal-btn"><strong>CURSO</strong> <span class="content">Data Science Methodology</span></div>
        <a href="{urls['github']}" target="_blank" class="reveal-btn"><strong>GITHUB</strong> <span class="content">@juanjararPYBM ↗</span></a>
    </div>
"""

description_component = """
    <div style="padding: 20px 0; border-top: 1px solid #f0f0f0;">
        <h4 style="color:var(--primary); font-family:'Montserrat',sans-serif; font-size:0.8em; text-transform:uppercase; margin:0 0 10px 0; letter-spacing:1px;">
            <strong>Descripción:</strong>
        </h4>
        <p style="color:#666; font-size:0.95em; margin-bottom:15px; line-height:1.5;">
            Es momento de demostrar su comprensión de la <b>metodología de ciencia de datos</b>. Aplicará el marco de trabajo <b>CRISP-DM</b> analizando el problema desde dos perspectivas fundamentales:
        </p>

        <div class="role-container">
            <div class="role-row role-client">
                <div class="role-label label-client">ROLE 1: EL CLIENTE</div>
                <span style="font-size:0.85em; color:#455a64;">Plantear un problema del mundo real como una pregunta basada en datos.</span>
            </div>
            <div class="role-row role-scientist">
                <div class="role-label label-scientist">ROLE 2: EL CIENTÍFICO</div>
                <span style="font-size:0.85em; color:#455a64;">Aplicar CRISP-DM para cerrar la brecha entre necesidades comerciales y técnicas.</span>
            </div>
        </div>
    </div>
"""

# =============================================================================
# MASTER INDEX V19: ENLACE FUNCIONAL FASE 2 & UNIFICACIÓN ESTÉTICA
# =============================================================================
from IPython.display import HTML, display

# 1. DICCIONARIO DE RUTAS (Actualizado con persistencia relativa)
urls = {
    "github": "https://github.com",
    "fase1": "./Fase1_Business_Understanding.ipynb",
    "fase2": "./Fase2_Data_Understanding.ipynb",
    "fase3": "#", "fase4": "#", "fase5": "#", "fase6": "#"
}

# 2. ESTILOS CSS UNIFICADOS (Sincronizados con el Diccionario Fase 2)
css_styles = f"""
<style>
    @import url('https://fonts.googleapis.com');

    :root {{
        --primary: #2e6171;    --f1-blue: #007bff;
        --f2-indigo: #6366f1;  --f3-orange: #ff7b00; /* F2 Actualizado a Indigo Slate */
        --f4-red: #ff2a00;     --f5-green: #27ae60;
        --f6-dark: #2c3e50;    --glass-bg: #f8f9fa;
    }}

    .master-container {{
        font-family: 'Inter', sans-serif; padding: 35px; background: white;
        border-radius: 20px; border: 1px solid #eef2f3; max-width: 950px; margin: auto;
        box-shadow: 0 10px 40px rgba(0,0,0,0.03);
    }}

    /* HEADER: Reveal dinámico */
    .reveal-group {{ display: flex; gap: 12px; margin-bottom: 25px; }}
    .reveal-btn {{
        padding: 8px 18px; border-radius: 50px; background: var(--glass-bg);
        border: 1px solid #e1e4e8; color: #455a64; font-size: 0.82em; cursor: pointer;
        transition: all 0.6s cubic-bezier(0.165, 0.84, 0.44, 1);
        display: inline-flex; align-items: center; overflow: hidden;
        max-width: 95px; white-space: nowrap; font-weight: 600; text-decoration: none;
    }}
    .reveal-btn strong {{ font-family: 'Montserrat'; color: var(--primary); flex-shrink: 0; }}
    .reveal-btn span {{ opacity: 0; transition: 0.3s; margin-left: 10px; }}
    .reveal-btn:hover {{ max-width: 600px; background: var(--primary) !important; color: white !important; }}
    .reveal-btn:hover strong {{ color: white !important; margin-right: 15px; }}
    .reveal-btn:hover span {{ opacity: 1; }}

    /* ÍNDICE: Estructura de Fases */
    .index-title {{
        color: #444; font-family: 'Montserrat'; font-size: 0.85em;
        text-transform: uppercase; margin: 45px 0 25px 0; letter-spacing: 3px;
        text-align: center; font-weight: 800; display: flex; align-items: center; justify-content: center; gap: 20px;
    }}
    .index-title::before, .index-title::after {{ content: ""; flex: 1; height: 1px; background: #ddd; }}

    .phase-list {{ display: flex; flex-direction: column; gap: 12px; }}
    .phase-item {{
        display: flex; align-items: center; padding: 16px 24px; border-radius: 12px;
        border: 1px solid #f2f2f2; text-decoration: none; color: #555; background: #fff;
        opacity: 0.85; transition: all 0.3s cubic-bezier(0.175, 0.885, 0.32, 1.275);
        position: relative;
    }}

    .phase-info {{ display: flex; align-items: center; flex-grow: 1; pointer-events: none; }}
    .phase-info strong {{ font-family: 'Montserrat'; font-size: 0.88em; min-width: 95px; }}
    .phase-desc {{ font-size: 0.88em; margin-left: 22px; color: #555; border-left: 1px solid #f0f0f0; padding-left: 18px; flex-grow: 1; }}

    .status-dot {{ width: 11px; height: 11px; border-radius: 50%; margin-left: 20px; transition: 0.3s; border: 1.5px solid rgba(0,0,0,0.1); }}
    .dot-green {{ background: #2ecc71; box-shadow: 0 0 10px rgba(46, 204, 113, 0.3); }}
    .dot-yellow {{ background: #f1c40f; box-shadow: 0 0 10px rgba(241, 196, 15, 0.3); }}
    .dot-red {{ background: #e74c3c; }}

    .nav-popup {{
        visibility: hidden; opacity: 0; position: absolute;
        right: 55px; top: 50%; transform: translateY(-50%) translateX(10px);
        background: #fff; padding: 6px 16px; border-radius: 20px;
        box-shadow: 0 6px 15px rgba(0,0,0,0.12); border: 1px solid #eee; transition: 0.4s ease;
    }}
    .nav-popup a {{ text-decoration: none !important; font-family: 'Montserrat'; font-weight: 800; font-size: 0.68em; text-transform: uppercase; color: inherit; }}

    /* Hover Fases */
    .phase-item:hover {{ opacity: 1; transform: translateY(-4px); color: white !important; }}
    .phase-item:hover .phase-desc {{ color: rgba(255,255,255,0.95); border-left-color: rgba(255,255,255,0.4); }}
    .phase-item:hover strong {{ color: white !important; }}
    .phase-item:hover .nav-popup {{ visibility: visible; opacity: 1; transform: translateY(-50%) translateX(0px); }}

    /* Colores Hover Sincronizados */
    .p1:hover {{ background: var(--f1-blue); border-color: var(--f1-blue); }}
    .p2:hover {{ background: var(--f2-indigo); border-color: var(--f2-indigo); }}
    .p3:hover {{ background: var(--f3-orange); border-color: var(--f3-orange); }}
    .p4:hover {{ background: var(--f4-red); border-color: var(--f4-red); }}
    .p5:hover {{ background: var(--f5-green); border-color: var(--f5-green); }}
    .p6:hover {{ background: var(--f6-dark); border-color: var(--f6-dark); }}
</style>
"""
# 1. CONFIGURACIÓN DE CONEXIÓN INTERACTIVA (Protocolo Completo)
colab_base = "https://colab.research.google.com/github"
repo_folder = "juanjararPYBM/ibm-data-science-portfolio/blob/main/proyecto_medico"

# 2. DICCIONARIO DE RUTAS (Fuerza la ejecución en Colab usando f-strings)
urls = {
    "github": "https://github.com",
    "fase1": f"{colab_base}/{repo_folder}/Fase1_Business_Understanding.ipynb",
    "fase2": f"{colab_base}/{repo_folder}/Fase2_Data_Understanding.ipynb",
    "fase2_eda": f"{colab_base}/{repo_folder}/fase2_EDA.ipynb", # <-- NUEVA RUTA
    "fase3": f"{colab_base}/{repo_folder}/Fase3_Data_Preparation.ipynb",
    "fase4": "#", "fase5": "#", "fase6": "#"
}

# 3. COMPONENTES HTML
header_component = f"""
<div class="master-container">
    <h1 style="color:var(--primary); font-family:'Montserrat'; font-weight:800; font-size:2.3em; margin-bottom:25px; letter-spacing:-1.5px;">
        IBM Data Science: Proyecto Final
    </h1>
    <div class="reveal-group">
        <div class="reveal-btn"><strong>AUTOR</strong> <span>Juan Pablo Jaramillo</span></div>
        <div class="reveal-btn"><strong>CURSO</strong> <span>Data Science Methodology</span></div>
        <a href="{urls['github']}" target="_blank" class="reveal-btn"><strong>GITHUB</strong> <span>@juanjararPYBM ↗</span></a>
    </div>
"""

nav_list_component = f"""
<div class="index-title">Índice de Módulos Interactivos</div>
<div class="phase-list">

    <!-- FASE 1 -->
    <div class="phase-item p1">
        <div class="phase-info"><strong>🔍 FASE 1</strong> <span class="phase-desc">Business Understanding</span></div>
        <a href="{urls['fase1']}" target="_blank" style="text-decoration: none;">
            <div class="nav-popup" style="cursor: pointer; display: block; padding: 5px 15px; background: var(--primary); color: white; border-radius: 5px; font-weight: bold;">
                EXPLORAR / EJECUTAR ↗
            </div>
        </a>
        <div class="status-dot dot-green"></div>
    </div>

    <!-- FASE 2 -->
    <div class="phase-item p2">
        <div class="phase-info"><strong>📊 FASE 2</strong> <span class="phase-desc">Data Understanding: Auditoría y calidad.</span></div>
        <a href="{urls['fase2']}" target="_blank" style="text-decoration: none;">
            <div class="nav-popup" style="cursor: pointer; display: block; padding: 5px 15px; background: var(--primary); color: white; border-radius: 5px; font-weight: bold;">
                EXPLORAR / EJECUTAR ↗
            </div>
        </a>
        <div class="status-dot dot-yellow"></div>
    </div>

    <!-- FASE 3 -->
    <div class="phase-item p3">
        <div class="phase-info"><strong>🛠️ FASE 3</strong> <span class="phase-desc">Data Preparation: Limpieza e ingeniería.</span></div>
        <a href="{urls['fase3']}" target="_blank" style="text-decoration: none;">
            <div class="nav-popup" style="cursor: pointer; display: block; padding: 5px 15px; background: var(--primary); color: white; border-radius: 5px; font-weight: bold;">
                EXPLORAR / EJECUTAR ↗
            </div>
        </a>
        <div class="status-dot dot-red"></div>
    </div>

    <!-- FASE 4 -->
    <div class="phase-item p4">
        <div class="phase-info"><strong>🤖 FASE 4</strong> <span class="phase-desc">Modeling: Entrenamiento y optimización.</span></div>
        <a href="{urls['fase4']}" target="_blank" style="text-decoration: none;">
            <div class="nav-popup" style="cursor: pointer; display: block; padding: 5px 15px; background: var(--primary); color: white; border-radius: 5px; font-weight: bold;">
                EXPLORAR / EJECUTAR ↗
            </div>
        </a>
        <div class="status-dot dot-red"></div>
    </div>

    <!-- FASE 5 -->
    <div class="phase-item p5">
        <div class="phase-info"><strong>🎯 FASE 5</strong> <span class="phase-desc">Evaluation: Validación y resultados.</span></div>
        <a href="{urls['fase5']}" target="_blank" style="text-decoration: none;">
            <div class="nav-popup" style="cursor: pointer; display: block; padding: 5px 15px; background: var(--primary); color: white; border-radius: 5px; font-weight: bold;">
                EXPLORAR / EJECUTAR ↗
            </div>
        </a>
        <div class="status-dot dot-red"></div>
    </div>

    <!-- FASE 6 -->
    <div class="phase-item p6">
        <div class="phase-info"><strong>🚀 FASE 6</strong> <span class="phase-desc">Deployment: Reporte y puesta en producción.</span></div>
        <a href="{urls['fase6']}" target="_blank" style="text-decoration: none;">
            <div class="nav-popup" style="cursor: pointer; display: block; padding: 5px 15px; background: var(--primary); color: white; border-radius: 5px; font-weight: bold;">
                EXPLORAR / EJECUTAR ↗
            </div>
        </a>
        <div class="status-dot dot-red"></div>
    </div>

</div> <!-- Cierre phase-list -->
</div> <!-- Cierre master-container -->
"""

# Renderizado Final
display(HTML(css_styles + header_component + nav_list_component))
# Out:
# <style>
#     @import url('https://fonts.googleapis.com');
#
#     :root {
#         --primary: #2e6171;    --f1-blue: #007bff;
#         --f2-indigo: #6366f1;  --f3-orange: #ff7b00; /* F2 Actualizado a Indigo Slate */
#         --f4-red: #ff2a00;     --f5-green: #27ae60;
#         --f6-dark: #2c3e50;    --glass-bg: #f8f9fa;
#     }
#
#     .master-container {
#         font-family: 'Inter', sans-serif; padding: 35px; background: white;
#         border-radius: 20px; border: 1px solid #eef2f3; max-width: 950px; margin: auto;
#         box-shadow: 0 10px 40px rgba(0,0,0,0.03);
#     }
#
#     /* HEADER: Reveal dinámico */
#     .reveal-group { display: flex; gap: 12px; margin-bottom: 25px; }
#     .reveal-btn {
#         padding: 8px 18px; border-radius: 50px; background: var(--glass-bg);
#         border: 1px solid #e1e4e8; color: #455a64; font-size: 0.82em; cursor: pointer;
#         transition: all 0.6s cubic-bezier(0.165, 0.84, 0.44, 1);
# ...
