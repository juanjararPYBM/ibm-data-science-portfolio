# %% [markdown]
# <a href="https://colab.research.google.com/github/juanjararPYBM/ibm-data-science-portfolio/blob/main/proyecto_medico/Master_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# MASTER INDEX V2.3 — PORTFOLIO IBM DATA SCIENCE
# CAMBIO vs V2.2: Fase 2 unificada → un solo botón, status done, badge V5.0
# =============================================================================
from IPython.display import HTML, display

colab_base  = "https://colab.research.google.com/github"
repo_folder = "juanjararPYBM/ibm-data-science-portfolio/blob/main/proyecto_medico"

urls = {
    "github": "https://github.com/juanjararPYBM/ibm-data-science-portfolio",
    "kaggle": "https://www.kaggle.com/datasets/jocelyndumlao/cardiovascular-disease-dataset",
    "esc":    "https://www.escardio.org/guidelines/clinical-practice-guidelines/all-esc-practice-guidelines/",
    "f1":     f"{colab_base}/{repo_folder}/Fase1_Business_Understanding.ipynb",
    "f2":     f"{colab_base}/{repo_folder}/Fase2_Data_Understanding.ipynb",
    "f3": "#", "f4": "#", "f5": "#", "f6": "#",
}

ui_styles = """
<style>
    @import url('https://fonts.googleapis.com/css2?family=JetBrains+Mono:wght@400;600;700;800&family=Inter:wght@300;400;600&display=swap');

    #main-ui {
        --cyan:   #00f2fe;
        --violet: #8b5cf6;
        --orange: #ff9500;
        --red:    #ff4444;
        --green:  #00ff88;
        --ice:    #e2e8f0;
        --bg:     #050a0f;
    }
    @property --angle { syntax:'<angle>'; initial-value:0deg; inherits:false; }
    @keyframes spin    { from{--angle:0deg} to{--angle:360deg} }
    @keyframes prog-in { from{width:0} to{width:var(--tw)} }
    @keyframes b-done  { 0%,100%{opacity:1;  box-shadow:0 0 7px #00ff88}  50%{opacity:0.5; box-shadow:0 0 14px #00ff88} }
    @keyframes b-wip   { 0%,100%{opacity:1;  box-shadow:0 0 6px #ff9500}  50%{opacity:0.25;box-shadow:0 0 2px  #ff9500} }
    @keyframes b-pend  { 0%,100%{opacity:0.2} 50%{opacity:0.07} }

    #main-ui {
        font-family:'Inter',sans-serif !important;
        max-width:980px; margin:50px auto;
        background:rgba(8,16,26,0.94) !important;
        backdrop-filter:blur(30px);
        border-radius:32px;
        border:1px solid rgba(255,255,255,0.09) !important;
        padding:48px 52px;
        color:#e2e8f0 !important;
        box-shadow:0 60px 120px rgba(0,0,0,0.9);
        position:relative;
    }
    #main-ui .mi-pretitle {
        font-size:0.75em; color:#475569 !important;
        letter-spacing:0.5px; margin-bottom:10px;
        font-family:'Inter',sans-serif !important;
    }
    #main-ui .mi-title {
        font-family:'JetBrains Mono',monospace !important;
        font-weight:900; font-size:2.1em;
        margin:0 0 28px; line-height:1.18;
        color:#ffffff !important;
    }
    #main-ui .mi-title span { color:#00f2fe !important; }
    #main-ui .mi-chips { display:flex; gap:8px; flex-wrap:wrap; margin-bottom:28px; }
    #main-ui .mi-chip {
        display:inline-flex; align-items:center; gap:6px;
        background:rgba(255,255,255,0.06) !important;
        border:1px solid rgba(255,255,255,0.12) !important;
        border-radius:50px; padding:5px 14px;
        font-family:'JetBrains Mono',monospace !important;
        font-size:0.7em; color:#94a3b8 !important; transition:0.3s;
    }
    #main-ui .mi-chip:hover { border-color:#00f2fe !important; background:rgba(0,242,254,0.08) !important; }
    #main-ui .mi-chip b { color:#00f2fe !important; font-weight:700; }
    #main-ui .reveal-group { display:flex; gap:10px; margin-bottom:30px; flex-wrap:wrap; }
    #main-ui .reveal-btn {
        padding:9px 16px; border-radius:50px;
        background:rgba(255,255,255,0.05) !important;
        border:1px solid rgba(255,255,255,0.13) !important;
        color:#e2e8f0 !important; font-size:0.74em; cursor:pointer;
        transition:all 0.55s cubic-bezier(0.165,0.84,0.44,1);
        display:inline-flex; align-items:center; overflow:hidden;
        max-width:115px; min-width:115px; white-space:nowrap;
        font-weight:600; text-decoration:none !important; position:relative;
        --p-color:#00f2fe;
    }
    #main-ui .reveal-btn:hover { max-width:400px !important; background:rgba(255,255,255,0.1) !important; transform:translateY(-3px); }
    #main-ui .reveal-btn::before {
        content:''; position:absolute; inset:0; padding:1.5px; border-radius:inherit;
        background:conic-gradient(from var(--angle),transparent 75%,var(--p-color) 85%,var(--p-color) 95%,transparent 100%);
        -webkit-mask:linear-gradient(#fff 0 0) content-box,linear-gradient(#fff 0 0);
        mask:linear-gradient(#fff 0 0) content-box,linear-gradient(#fff 0 0);
        -webkit-mask-composite:xor; mask-composite:exclude; opacity:0; transition:0.3s;
    }
    #main-ui .reveal-btn:hover::before { opacity:1; animation:spin 2s linear infinite; }
    #main-ui .reveal-btn strong {
        font-family:'JetBrains Mono',monospace !important;
        color:var(--p-color) !important; flex-shrink:0; margin-right:12px; font-size:0.88em;
    }
    #main-ui .reveal-btn span {
        opacity:0; transition:0.4s; color:#e2e8f0 !important;
        font-family:'JetBrains Mono',monospace !important;
    }
    #main-ui .reveal-btn:hover span { opacity:1; }
    #main-ui .rb-violet { --p-color:#8b5cf6; }
    #main-ui .rb-esc    { --p-color:#e2e8f0; }
    #main-ui .mi-prog-wrap { margin-bottom:32px; }
    #main-ui .mi-prog-head {
        display:flex; justify-content:space-between;
        font-family:'JetBrains Mono',monospace !important;
        font-size:0.6em; letter-spacing:2px;
        color:#334155 !important; margin-bottom:10px;
    }
    #main-ui .mi-prog-pct { color:#00ff88 !important; font-weight:900; }
    #main-ui .mi-prog-track {
        height:3px; background:rgba(255,255,255,0.07);
        border-radius:2px; position:relative;
    }
    #main-ui .mi-prog-fill {
        height:100%; border-radius:2px;
        background:linear-gradient(90deg,#00f2fe,#8b5cf6);
        box-shadow:0 0 14px #00f2fe;
        --tw:33.3%; animation:prog-in 1.8s cubic-bezier(0.4,0,0.2,1) 0.4s both;
        width:var(--tw);
    }
    #main-ui .mi-prog-dot {
        position:absolute; top:-4px; width:10px; height:10px;
        border-radius:50%; border:2px solid #080f18; transform:translateX(-50%);
    }
    #main-ui .crisp-div {
        display:flex; align-items:center; margin:26px 0 12px;
        font-family:'JetBrains Mono',monospace !important;
        font-size:0.58em; letter-spacing:5px;
        color:#1e3a4a !important; font-weight:900;
    }
    #main-ui .crisp-div::before, #main-ui .crisp-div::after {
        content:''; flex:1; height:1px;
        background:linear-gradient(90deg,transparent,rgba(255,255,255,0.08),transparent);
    }
    #main-ui .crisp-div::before { margin-right:18px; }
    #main-ui .crisp-div::after  { margin-left:18px; }
    #main-ui .phase-row {
        position:relative !important; overflow:hidden; margin-bottom:9px !important;
        background:rgba(255,255,255,0.04) !important;
        border:1px solid rgba(255,255,255,0.09) !important;
        transition:all 0.38s cubic-bezier(0.165,0.84,0.44,1);
        border-radius:18px !important; padding:18px 24px !important;
        display:flex !important; align-items:center !important; gap:14px;
        --p-color:#00f2fe; min-height:58px !important;
        box-sizing:border-box !important; visibility:visible !important;
        opacity:1 !important; height:auto !important;
    }
    #main-ui .phase-row:hover {
        transform:translateX(5px);
        background:rgba(255,255,255,0.07) !important;
        border-color:var(--p-color) !important;
        box-shadow:0 0 18px -4px var(--p-color), inset 0 0 30px -20px var(--p-color) !important;
    }
    #main-ui .f1{--p-color:#00f2fe}  #main-ui .f2{--p-color:#8b5cf6}
    #main-ui .f3{--p-color:#ff9500}  #main-ui .f4{--p-color:#ff4444}
    #main-ui .f5{--p-color:#00ff88}  #main-ui .f6{--p-color:#e2e8f0}
    #main-ui .ph-num {
        font-family:'JetBrains Mono',monospace !important; font-size:0.68em; font-weight:900 !important;
        color:#4a6080 !important; min-width:58px; flex-shrink:0; transition:0.35s;
    }
    #main-ui .phase-row:hover .ph-num { color:var(--p-color) !important; text-shadow:0 0 10px var(--p-color); }
    #main-ui .ph-info { flex-grow:1 !important; min-width:0; display:block !important; }
    #main-ui .ph-name {
        font-weight:500 !important; font-size:0.95em;
        color:#c8d8e8 !important; transition:0.3s; line-height:1.3;
        font-family:'Inter',sans-serif !important;
    }
    #main-ui .phase-row:hover .ph-name { color:#ffffff !important; }
    #main-ui .ph-sub {
        font-size:0.68em; color:#3a5570 !important; margin-top:4px;
        font-family:'JetBrains Mono',monospace !important; transition:0.3s;
        white-space:nowrap; overflow:hidden; text-overflow:ellipsis;
    }
    #main-ui .phase-row:hover .ph-sub { color:#5a7590 !important; }
    #main-ui .st-dot { width:11px; height:11px; border-radius:50%; flex-shrink:0; }
    #main-ui .st-done { background:#00ff88; animation:b-done 2.5s ease-in-out infinite; }
    #main-ui .st-wip  { background:#ff9500; animation:b-wip  1.4s ease-in-out infinite; }
    #main-ui .st-pend { background:#1a2c3d; animation:b-pend 3s   ease-in-out infinite; border:1px solid #253545; }
    #main-ui .btn-grp { display:flex; gap:7px; flex-shrink:0; }
    #main-ui .btn-act {
        padding:6px 14px; border-radius:18px; font-weight:700; font-size:0.63em;
        letter-spacing:0.5px; text-transform:uppercase; text-decoration:none !important;
        color:#e2e8f0 !important; background:rgba(255,255,255,0.07) !important;
        border:1px solid rgba(255,255,255,0.13) !important;
        transition:all 0.32s cubic-bezier(0.34,1.56,0.64,1);
        display:inline-flex; align-items:center; font-family:'JetBrains Mono',monospace !important;
        --p-color:#00f2fe;
    }
    #main-ui .btn-act:hover {
        background:var(--p-color) !important; color:#000 !important;
        box-shadow:0 6px 20px -4px var(--p-color);
        transform:translateY(-2px) scale(1.06);
        border-color:transparent !important;
    }
    #main-ui .ba1{--p-color:#00f2fe}  #main-ui .ba2{--p-color:#8b5cf6}
    #main-ui .ba3{--p-color:#ff9500}  #main-ui .ba4{--p-color:#ff4444}
    #main-ui .ba5{--p-color:#00ff88}  #main-ui .ba6{--p-color:#e2e8f0}

    /* ── V2.3: badge versión en phase-row ── */
    #main-ui .ph-badge {
        font-family:'JetBrains Mono',monospace !important;
        font-size:0.58em; font-weight:700; padding:2px 8px;
        border-radius:6px; letter-spacing:1px; flex-shrink:0;
        background:rgba(139,92,246,.15); color:#a78bfa !important;
        border:1px solid rgba(139,92,246,.3);
    }

    #main-ui .mi-legend {
        display:flex; gap:20px; justify-content:center;
        margin-top:24px; padding-top:18px;
        border-top:1px solid rgba(255,255,255,0.06);
        font-family:'JetBrains Mono',monospace !important;
        font-size:0.65em; color:#3a5060 !important;
    }
    #main-ui .leg-item { display:flex; align-items:center; gap:7px; }
    #main-ui .leg-dot  { width:9px; height:9px; border-radius:50%; flex-shrink:0; }
    #main-ui .mi-footer {
        display:flex; justify-content:space-between; align-items:center;
        margin-top:14px; font-size:0.65em; color:#1e3040 !important;
        font-family:'JetBrains Mono',monospace !important;
    }
    #main-ui .mi-footer span:hover { color:#00f2fe !important; transition:0.3s; cursor:default; }
</style>
"""

ui_content = f"""
<div id="main-ui">

    <p class="mi-pretitle">IBM Data Science Professional Certificate &nbsp;·&nbsp; CRISP-DM &nbsp;·&nbsp; Predicción de Riesgo Cardiovascular</p>
    <h1 class="mi-title">CARDIORISK<br><span>CLASIFICACIÓN ISQUÉMICA</span></h1>

    <div class="mi-chips">
        <div class="mi-chip"><b>1,000</b>&nbsp;pacientes</div>
        <div class="mi-chip"><b>14</b>&nbsp;variables clínicas</div>
        <div class="mi-chip"><b>Binario</b>&nbsp;clasificación</div>
        <div class="mi-chip"><b>KaggleHub</b>&nbsp;fuente</div>
        <div class="mi-chip"><b>Recall ↑</b>&nbsp;métrica primaria</div>
    </div>

    <div class="reveal-group">
        <a href="{urls['github']}" target="_blank" class="reveal-btn"><strong>GITHUB</strong><span>juanjararPYBM ↗</span></a>
        <a href="{urls['kaggle']}" target="_blank" class="reveal-btn rb-violet"><strong>DATASET</strong><span>Cardiovascular ↗</span></a>
        <a href="{urls['esc']}"    target="_blank" class="reveal-btn rb-esc"><strong>ESC</strong><span>Guidelines Clínicas ↗</span></a>
    </div>

    <div class="mi-prog-wrap">
        <div class="mi-prog-head">
            <span>AVANCE DEL PORTFOLIO</span>
            <span class="mi-prog-pct">2 / 6 FASES COMPLETADAS</span>
        </div>
        <div class="mi-prog-track">
            <div class="mi-prog-fill"></div>
            <div class="mi-prog-dot" style="left:16.6%;background:#00f2fe;"></div>
            <div class="mi-prog-dot" style="left:33.3%;background:#8b5cf6;"></div>
            <div class="mi-prog-dot" style="left:50%;  background:#1a2535;"></div>
            <div class="mi-prog-dot" style="left:66.6%;background:#1a2535;"></div>
            <div class="mi-prog-dot" style="left:83.3%;background:#1a2535;"></div>
            <div class="mi-prog-dot" style="left:100%; background:#1a2535;"></div>
        </div>
    </div>

    <div class="crisp-div">Business &amp; Data Understanding</div>

    <div class="phase-row f1">
        <div class="ph-num">FASE 1</div>
        <div class="ph-info">
            <div class="ph-name">Business Understanding</div>
            <div class="ph-sub">Estrategia · Stakeholders · KPIs · EWS · ROI</div>
        </div>
        <div class="st-dot st-done"></div>
        <div class="btn-grp">
            <a href="{urls['f1']}" target="_blank" class="btn-act ba1">EXPLORAR ↗</a>
        </div>
    </div>

    <div class="phase-row f2">
        <div class="ph-num">FASE 2</div>
        <div class="ph-info">
            <div class="ph-name">Data Understanding &amp; EDA</div>
            <div class="ph-sub">Setup · Diccionario · Distribuciones · Correlaciones · Multivariado · Conclusiones</div>
        </div>
        <div class="ph-badge">V5.0</div>
        <div class="st-dot st-done"></div>
        <div class="btn-grp">
            <a href="{urls['f2']}" target="_blank" class="btn-act ba2">EXPLORAR ↗</a>
        </div>
    </div>

    <div class="crisp-div">Data Preparation</div>

    <div class="phase-row f3">
        <div class="ph-num">FASE 3</div>
        <div class="ph-info">
            <div class="ph-name">Data Preparation</div>
            <div class="ph-sub">Limpieza · Feature Engineering · Normalización · Splits</div>
        </div>
        <div class="st-dot st-pend"></div>
        <div class="btn-grp"><a href="#" class="btn-act ba3">PRÓXIMO ↗</a></div>
    </div>

    <div class="crisp-div">Modeling &amp; Evaluation</div>

    <div class="phase-row f4">
        <div class="ph-num">FASE 4</div>
        <div class="ph-info">
            <div class="ph-name">Modeling</div>
            <div class="ph-sub">Clasificadores · Hiperparámetros · Validación Cruzada</div>
        </div>
        <div class="st-dot st-pend"></div>
        <div class="btn-grp"><a href="#" class="btn-act ba4">PRÓXIMO ↗</a></div>
    </div>

    <div class="phase-row f5">
        <div class="ph-num">FASE 5</div>
        <div class="ph-info">
            <div class="ph-name">Evaluation</div>
            <div class="ph-sub">AUC-ROC · Recall · Matriz de Confusión · Análisis de Error</div>
        </div>
        <div class="st-dot st-pend"></div>
        <div class="btn-grp"><a href="#" class="btn-act ba5">PRÓXIMO ↗</a></div>
    </div>

    <div class="crisp-div">Deployment</div>

    <div class="phase-row f6">
        <div class="ph-num">FASE 6</div>
        <div class="ph-info">
            <div class="ph-name">Deployment — Reporte Médico Final</div>
            <div class="ph-sub">Informe Clínico · Dashboard · Recomendaciones · Entrega</div>
        </div>
        <div class="st-dot st-pend"></div>
        <div class="btn-grp"><a href="#" class="btn-act ba6">PRÓXIMO ↗</a></div>
    </div>

    <div class="mi-legend">
        <div class="leg-item"><div class="leg-dot" style="background:#00ff88;box-shadow:0 0 6px #00ff88"></div><span>Completado</span></div>
        <div class="leg-item"><div class="leg-dot" style="background:#ff9500;box-shadow:0 0 6px #ff9500"></div><span>En desarrollo</span></div>
        <div class="leg-item"><div class="leg-dot" style="background:#1a2c3d;border:1px solid #253545"></div><span>Pendiente</span></div>
    </div>

    <div class="mi-footer">
        <span>juanjararPYBM · IBM Data Science · 2025</span>
        <span>Master Index V2.3</span>
    </div>

</div>
"""

ui_scripts = """
<script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.12.2/gsap.min.js"></script>
<script>
(function() {
    var init = function() {
        gsap.from('#main-ui',   { duration:1.4, y:35,     opacity:0, ease:'expo.out' });
        gsap.from('.mi-chip',   { duration:0.4, scale:0.88,opacity:0, stagger:0.07, ease:'back.out(1.5)', delay:0.3 });
        gsap.from('.phase-row', { duration:0.5, y:10,     opacity:0, stagger:0.09, ease:'power3.out',    delay:0.5 });
    };
    if (window.gsap) init();
    else { var s = document.querySelector('script[src*="gsap"]'); if(s) s.onload = init; }
})();
</script>
"""

display(HTML(ui_styles + ui_content + ui_scripts))
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=JetBrains+Mono:wght@400;600;700;800&family=Inter:wght@300;400;600&display=swap');
#
#     #main-ui {
#         --cyan:   #00f2fe;
#         --violet: #8b5cf6;
#         --orange: #ff9500;
#         --red:    #ff4444;
#         --green:  #00ff88;
#         --ice:    #e2e8f0;
#         --bg:     #050a0f;
#     }
#     @property --angle { syntax:'<angle>'; initial-value:0deg; inherits:false; }
#     @keyframes spin    { from{--angle:0deg} to{--angle:360deg} }
#     @keyframes prog-in { from{width:0} to{width:var(--tw)} }
#     @keyframes b-done  { 0%,100%{opacity:1;  box-shadow:0 0 7px #00ff88}  50%{opacity:0.5; box-shadow:0 0 14px #00ff88} }
#     @keyframes b-wip   { 0%,100%{opacity:1;  box-shadow:0 0 6px #ff9500}  50%{opacity:0.25;box-shadow:0 0 2px  #ff9500} }
#     @keyframes b-pend  { 0%,100%{opacity:0.2} 50%{opacity:0.07} }
#
#     #main-ui {
#         font-family:'Inter',sans-serif !important;
# ...
