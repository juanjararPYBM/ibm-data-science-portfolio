# %%
# -*- coding: utf-8 -*-
"""Fase1_Business_Understanding.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/github/juanjararPYBM/ibm-data-science-portfolio/blob/main/proyecto_medico/Fase1_Business_Understanding.ipynb
"""

# =============================================================================
# PROYECTO: PORTAFOLIO IBM DATA SCIENCE - FASE 1 (BUSINESS UNDERSTANDING)
# VERSIÓN: 32.0 - SISTEMA DE DISEÑO UNIFICADO
# CAMBIOS vs V.31:
#   BUG-04: Google Fonts URL con parámetros completos
#   FONT:   Orbitron → JetBrains Mono 800
#   AUDIT:  EWS umbrales numéricos + ROI metodología
# =============================================================================
from IPython.display import HTML, display, clear_output

# --- MÓDULO 1: RUTAS ---
URL_AUTOR = "https://github.com/juanjararPYBM/ibm-data-science-portfolio"
URL_INDEX = "https://colab.research.google.com/github/juanjararPYBM/ibm-data-science-portfolio/blob/main/proyecto_medico/Master_Index.ipynb"
URL_KAGGLE = "https://www.kaggle.com/datasets/jocelyndumlao/cardiovascular-disease-dataset"
URL_CDSS = "https://pmc.ncbi.nlm.nih.gov/articles/PMC7005290/"
URL_Series = "https://www.ibm.com/think/topics/time-series-model"
URL_Def = "https://www.ncbi.nlm.nih.gov/books/NBK545216/"
URL_KPI = "https://www.kpi.org/kpi-basics/"
URL_DANE = "https://www.dane.gov.co/files/operaciones/EEVV/2024/19-dic-2024/bol-EEVV-Defunciones-2024pr.pdf"
URL_ESC = "https://www.escardio.org/guidelines/clinical-practice-guidelines/all-esc-practice-guidelines/"
URL_hl7 = "https://www.hl7.org/implement/standards/index.cfm"
URL_F2   = "https://colab.research.google.com/github/juanjararPYBM/ibm-data-science-portfolio/blob/main/proyecto_medico/Fase2_Data_Understanding.ipynb"

# ── MÓDULO 2: DICCIONARIO CLÍNICO V.10.2 eliminado → reubicado en Fase 2 ──
# --- MÓDULO 3: ESTILOS V.32 (V.31 + JetBrains Mono) ---
f1_styles = """
<style>
    @import url('https://fonts.googleapis.com/css2?family=JetBrains+Mono:wght@400;600;700;800&family=Inter:wght@300;400;600&display=swap');
    :root { --cyan: #00f2fe; --red: #ff4444; --green: #00ff88; --kaggle: #20beff; --bg: #050a0f; --p-color: var(--cyan); --f2-violet: #8b5cf6; --arctic: #f8fafc; --orange: #f59e0b; --pink: #ff69b4; }
    .master-container { font-family: 'Inter', sans-serif; max-width: 950px; margin: 40px auto; background: rgba(10, 20, 30, 0.75); backdrop-filter: blur(30px); border-radius: 35px; border: 1px solid rgba(255, 255, 255, 0.1); padding: 45px; color: white; box-shadow: 0 50px 100px rgba(0,0,0,0.8); position: relative; }
    @property --angle { syntax: '<angle>'; initial-value: 0deg; inherits: false; }
    @keyframes spin { from { --angle: 0deg; } to { --angle: 360deg; } }
    @keyframes pulse { 0% { transform: scale(0.95); box-shadow: 0 0 0 0 rgba(255, 68, 68, 0.8); } 70% { transform: scale(1.1); box-shadow: 0 0 0 14px rgba(255, 68, 68, 0); } 100% { transform: scale(0.95); box-shadow: 0 0 0 0 rgba(255, 68, 68, 0); } }
    .bg-particles { position: fixed; top: 0; left: 0; width: 100%; height: 100%; pointer-events: none; z-index: 0; overflow: hidden; }
    .particle { position: absolute; width: 4px; height: 4px; background: var(--cyan); border-radius: 50%; opacity: 0.3; animation: float 20s infinite; }
    @keyframes float { 0%, 100% { transform: translateY(0) translateX(0); } 25% { transform: translateY(-30px) translateX(15px); } 50% { transform: translateY(-15px) translateX(-10px); } 75% { transform: translateY(-45px) translateX(20px); } }

    /* Botones Reveal */
    .reveal-group { display: flex; gap: 12px; margin-bottom: 35px; position: relative; z-index: 10; }
    .reveal-btn { padding: 10px 18px !important; border-radius: 50px; background: rgba(255, 255, 255, 0.03); border: 1px solid rgba(255, 255, 255, 0.1); color: white !important; font-size: 0.75em; cursor: pointer; transition: all 0.6s cubic-bezier(0.4, 0, 0.2, 1); display: inline-flex; align-items: center; overflow: hidden; max-width: 115px; min-width: 115px; white-space: nowrap; font-weight: 600; text-decoration: none; position: relative; }
    .reveal-btn:hover { max-width: 450px !important; background: rgba(255, 255, 255, 0.08) !important; transform: translateY(-4px); box-shadow: 0 20px 50px rgba(0, 242, 254, 0.25); }
    .reveal-btn::before { content: ''; position: absolute; inset: 0; padding: 1px; border-radius: inherit; background: conic-gradient(from var(--angle), transparent 75%, var(--p-color) 85%, var(--p-color) 95%, transparent 100%); -webkit-mask: linear-gradient(#fff 0 0) content-box, linear-gradient(#fff 0 0); mask: linear-gradient(#fff 0 0) content-box, linear-gradient(#fff 0 0); -webkit-mask-composite: xor; mask-composite: exclude; opacity: 0; transition: 0.4s ease; pointer-events: none; }
    .reveal-btn:hover::before { opacity: 1; animation: spin 2s linear infinite; }
    .reveal-btn strong { font-family: 'JetBrains Mono', monospace; color: var(--p-color); flex-shrink: 0; margin-right: 15px; transition: 0.4s ease; }
    .reveal-btn:hover strong { text-shadow: 0 0 20px var(--p-color); }
    .reveal-btn span { opacity: 0; transition: 0.5s ease; pointer-events: none; color: #ffffff !important; font-family: 'JetBrains Mono', monospace; }
    .reveal-btn:hover span { opacity: 1; }
    .reveal-btn.btn-cyan { --p-color: var(--cyan); }
    .reveal-btn.btn-kaggle { --p-color: var(--kaggle); }
    .reveal-btn.btn-f2 { --p-color: var(--f2-violet); }

    /* Filas de Fase — layout de V.31 intacto */
    .phase-row { position: relative; overflow: hidden; margin-bottom: 12px; background: rgba(255, 255, 255, 0.03); border: 1px solid rgba(255, 255, 255, 0.07); transition: all 0.4s cubic-bezier(0.165, 0.84, 0.44, 1); border-radius: 20px; padding: 25px 35px; display: flex; align-items: center; z-index: 2; --p-color: var(--cyan); }
    .f-red { --p-color: var(--red); background: rgba(255, 68, 68, 0.04) !important; border-color: rgba(255, 68, 68, 0.15) !important; }
    .f-green { --p-color: var(--green); background: rgba(0, 255, 136, 0.04) !important; border-color: rgba(0, 255, 136, 0.15) !important; }
    .f-violet { --p-color: var(--f2-violet); background: rgba(139, 92, 246, 0.04) !important; border-color: rgba(139, 92, 246, 0.15) !important; }
    .phase-row:hover { transform: translateX(8px); }
    .phase-row::before { content: ''; position: absolute; inset: 0; padding: 2px; border-radius: inherit; background: conic-gradient(from var(--angle), transparent 75%, var(--p-color) 85%, var(--p-color) 95%, transparent 100%); -webkit-mask: linear-gradient(#fff 0 0) content-box, linear-gradient(#fff 0 0); mask: linear-gradient(#fff 0 0) content-box, linear-gradient(#fff 0 0); -webkit-mask-composite: xor; mask-composite: exclude; opacity: 0; transition: 0.3s; }
    .phase-row:hover::before { opacity: 1; animation: spin 1.5s linear infinite; }
    .phase-label { font-family: 'JetBrains Mono', monospace; font-size: 0.8em; width: 135px; font-weight: 800; color: #666; transition: 0.4s; }
    .phase-row:hover .phase-label { color: var(--p-color); text-shadow: 0 0 15px var(--p-color), 0 0 30px var(--p-color); }
    .phase-name { font-weight: 300; font-size: 1.02em; flex-grow: 1; opacity: 0.7; transition: 0.4s; line-height: 1.6; color: #eee; }
    .phase-row:hover .phase-name { opacity: 1; color: white; }
    .obj-divider { display: flex; align-items: center; text-align: center; margin: 35px 0 25px 0; font-family: 'JetBrains Mono', monospace; font-size: 0.85em; letter-spacing: 6px; color: #555; font-weight: 800; }
    .obj-divider::before, .obj-divider::after { content: ''; flex: 1; border-bottom: 1px solid rgba(255,255,255,0.08); margin: 0 20px; }

    /* Status Dots */
    .dot-status { width: 10px; height: 10px; border-radius: 50%; flex-shrink: 0; }
    .dot-low { background: var(--green); box-shadow: 0 0 10px var(--green); }
    .dot-mid { background: var(--orange); box-shadow: 0 0 10px var(--orange); }
    .dot-high { background: var(--red); animation: pulse 1.5s infinite; }

    /* Tags */
    .tag-pill, .tag-type { padding: 4px 10px; border-radius: 6px; font-size: 0.65em; font-family: 'JetBrains Mono', monospace; background: rgba(255,255,255,0.05); color: #64748b; border: 1px solid rgba(255,255,255,0.1); transition: 0.3s; text-transform: uppercase; font-weight: 800; }

    /* Team Cards */
    .team-grid { display: grid; grid-template-columns: repeat(2, 1fr); gap: 15px; margin-top: 15px; }
    .team-card { background: rgba(255,255,255,0.03); border: 1px solid rgba(255,255,255,0.08); border-radius: 15px; padding: 15px; transition: 0.4s; }
    .team-card:hover { background: rgba(139, 92, 246, 0.08); border-color: var(--f2-violet); transform: translateY(-2px); }
    .team-role { font-family: 'JetBrains Mono', monospace; font-size: 0.7em; color: var(--f2-violet); font-weight: 700; margin-bottom: 5px; }
    .team-desc { font-size: 0.8em; opacity: 0.7; line-height: 1.4; }

    /* Timeline */
    .timeline { position: relative; padding-left: 30px; margin-top: 15px; }
    .timeline::before { content: ''; position: absolute; left: 8px; top: 0; bottom: 0; width: 2px; background: linear-gradient(to bottom, var(--cyan), var(--f2-violet), var(--green)); }
    .timeline-item { position: relative; margin-bottom: 20px; padding-left: 20px; }
    .timeline-item::before { content: ''; position: absolute; left: -26px; top: 5px; width: 12px; height: 12px; border-radius: 50%; background: var(--cyan); box-shadow: 0 0 10px var(--cyan); }
    .timeline-item:nth-child(2)::before { background: var(--f2-violet); box-shadow: 0 0 10px var(--f2-violet); }
    .timeline-item:nth-child(3)::before { background: var(--green); box-shadow: 0 0 10px var(--green); }
    .timeline-item:nth-child(4)::before { background: var(--orange); box-shadow: 0 0 10px var(--orange); }
    .timeline-week { font-size: 0.7em; color: var(--cyan); font-weight: 700; font-family: 'JetBrains Mono', monospace; }
    .timeline-phase { font-size: 0.85em; font-weight: 600; margin: 3px 0; }
    .timeline-desc { font-size: 0.75em; opacity: 0.6; }

    /* Stakeholder Table */
    .stakeholder-table { width: 100%; border-collapse: collapse; margin-top: 15px; font-size: 0.8em; }
    .stakeholder-table th { text-align: left; padding: 10px; background: rgba(139, 92, 246, 0.1); border-bottom: 1px solid rgba(255,255,255,0.1); color: var(--f2-violet); font-family: 'JetBrains Mono', monospace; font-size: 0.7em; text-transform: uppercase; }
    .stakeholder-table td { padding: 10px; border-bottom: 1px solid rgba(255,255,255,0.05); }
    .stakeholder-table tr:hover { background: rgba(139, 92, 246, 0.05); }

    /* Cost Cards */
    .cost-grid { display: grid; grid-template-columns: repeat(3, 1fr); gap: 15px; margin-top: 15px; }
    .cost-card { background: rgba(255,255,255,0.03); border-radius: 15px; padding: 20px; text-align: center; border: 1px solid rgba(255,255,255,0.05); transition: all 0.4s cubic-bezier(0.4, 0, 0.2, 1); }
    .cost-card:hover { transform: translateY(-5px); box-shadow: 0 15px 40px rgba(0, 242, 254, 0.2); border-color: var(--cyan); background: rgba(0, 242, 254, 0.08); }
    .cost-card.highlight { background: rgba(0, 255, 136, 0.08); border-color: var(--green); }
    .cost-card.highlight:hover { box-shadow: 0 15px 40px rgba(0, 255, 136, 0.3); }
    .cost-value { font-family: 'JetBrains Mono', monospace; font-size: 1.4em; color: var(--green); font-weight: 800; transition: 0.3s; }
    .cost-card:hover .cost-value { text-shadow: 0 0 20px var(--green); }
    .cost-label { font-size: 0.7em; opacity: 0.6; margin-top: 5px; text-transform: uppercase; }
    .cost-box { padding: 15px; border-radius: 12px; border-left: 3px solid; transition: all 0.4s cubic-bezier(0.4, 0, 0.2, 1); }
    .cost-box-fn { background: rgba(255,68,68,0.05); border-color: var(--red); }
    .cost-box-fn:hover { background: rgba(255,68,68,0.15); box-shadow: 0 0 30px rgba(255, 68, 68, 0.3); transform: translateX(5px); }
    .cost-box-fp { background: rgba(245,158,11,0.05); border-color: var(--orange); }
    .cost-box-fp:hover { background: rgba(245,158,11,0.15); box-shadow: 0 0 30px rgba(245, 158, 11, 0.3); transform: translateX(5px); }

    /* Assumptions */
    .assumptions-list { margin-top: 15px; }
    .assumption-item { display: flex; align-items: flex-start; gap: 12px; padding: 12px 0; border-bottom: 1px solid rgba(255,255,255,0.05); font-size: 0.85em; }
    .assumption-icon { color: var(--cyan); font-size: 1.2em; }

    /* Workflow */
    .workflow-steps { display: flex; gap: 10px; margin-top: 15px; flex-wrap: wrap; }
    .workflow-step { flex: 1; min-width: 120px; background: rgba(255,255,255,0.03); border-radius: 12px; padding: 15px; text-align: center; border: 1px solid rgba(255,255,255,0.08); transition: 0.4s; }
    .workflow-step:hover { background: rgba(0, 242, 254, 0.08); border-color: var(--cyan); }
    .workflow-num { width: 25px; height: 25px; border-radius: 50%; background: var(--cyan); color: black; font-weight: 700; font-size: 0.75em; display: flex; align-items: center; justify-content: center; margin: 0 auto 10px; }
    .workflow-text { font-size: 0.75em; opacity: 0.8; }

    /* Referencias */
    .references-grid { display: grid; grid-template-columns: 1fr 1fr; gap: 20px; font-size: 0.82em; opacity: 0.7; padding: 0 35px; font-weight: 300; line-height: 1.8; padding-bottom: 50px; }
    .ref-link { color: var(--cyan) !important; text-decoration: none !important; transition: 0.3s; }
    .ref-link:hover { text-shadow: 0 0 15px var(--cyan); opacity: 1; }


    /* ACCORDION COSTOS */
    .acc-kpi-row { display:grid; grid-template-columns:repeat(3,1fr); gap:15px; margin-top:15px; }
    .acc-kpi { text-align:center; padding:20px; background:rgba(255,255,255,0.03); border-radius:14px; border:1px solid rgba(255,255,255,0.07); transition:0.4s; }
    .acc-kpi:hover { transform:translateY(-4px); box-shadow:0 12px 35px rgba(0,255,136,0.15); border-color:rgba(0,255,136,0.3); }
    .acc-kpi-val { font-family:'JetBrains Mono',monospace; font-size:1.5em; color:#00ff88; font-weight:800; }
    .acc-kpi-lbl { font-size:0.65em; color:#475569; margin-top:4px; text-transform:uppercase; letter-spacing:1px; }
    .acc-trigger { width:100%; margin-top:14px; padding:10px; background:rgba(0,255,136,0.05); border:1px dashed rgba(0,255,136,0.2); border-radius:10px; cursor:pointer; font-family:'JetBrains Mono',monospace; font-size:0.68em; color:#475569; text-align:center; letter-spacing:1px; transition:0.3s; }
    .acc-trigger:hover { background:rgba(0,255,136,0.1); color:#00ff88; border-color:rgba(0,255,136,0.4); }

    @media (max-width: 768px) {
        .master-container { padding: 20px; margin: 20px auto; border-radius: 20px; }
        .phase-row { flex-direction: column; align-items: flex-start; padding: 20px; }
        .phase-label { width: 100%; margin-bottom: 10px; }
        .reveal-group { flex-direction: column; }
        .reveal-btn { max-width: 100% !important; min-width: 100%; }
        .team-grid, .cost-grid { grid-template-columns: 1fr; }
        .references-grid { grid-template-columns: 1fr; }
    }
</style>
"""

# --- MÓDULO 4: CUERPO HTML V.32 ---
f1_body = f"""
<div class="master-container" id="main-f1-ui">
    <div class="header-section">
        <h1 style="font-family:'JetBrains Mono',monospace; font-weight:800; font-size:2.4em; margin:0; line-height:1.2; color:var(--cyan)">Fase 1: Business Understanding</h1>
        <p style="color: #666; font-size: 1.05em; margin-bottom: 35px; font-weight: 600; letter-spacing: 0.5px;">Estrategia IBM Data Science / CRISP-DM Framework</p>
        <div class="reveal-group">
            <a href="{URL_AUTOR}" target="_blank" class="reveal-btn btn-cyan"><strong>AUTOR</strong> <span>/ juanjararPYBM</span></a>
            <a href="{URL_INDEX}" target="_blank" class="reveal-btn btn-cyan"><strong>INDEX</strong> <span>/ Master Portfolio ↗</span></a>
            <a href="{URL_KAGGLE}" target="_blank" class="reveal-btn btn-kaggle"><strong>KAGGLE</strong> <span>/ Heart Dataset ↗</span></a>
            <a href="{URL_F2}" target="_blank" class="reveal-btn btn-f2"><strong>FASE 2</strong> <span>/ Data Understanding ↗</span></a>
        </div>
    </div>


    <!-- ÍNDICE GRID -->
    <div style="background:rgba(255,255,255,0.03);border:1px solid rgba(255,255,255,0.07);border-radius:16px;padding:20px 24px;margin-bottom:28px;">
        <div style="font-family:'JetBrains Mono',monospace;font-size:0.65em;font-weight:800;color:#334155;letter-spacing:3px;text-transform:uppercase;margin-bottom:14px;">📋 Contenido</div>
        <div style="display:grid;grid-template-columns:repeat(4,1fr);gap:8px;">
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Desafío y Riesgo</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Estrategia y EWS</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Equipo</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Cronograma</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Stakeholders</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Costos y ROI</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Supuestos</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Workflow Clínico</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Arquitectura</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Ética y Gobernanza</div>
            <div style="font-family:'JetBrains Mono',monospace;font-size:0.68em;color:#64748b;padding:7px 12px;border-radius:8px;border:1px solid rgba(255,255,255,0.06);transition:all 0.25s;cursor:default;" onmouseover="this.style.color='#f8fafc';this.style.borderColor='rgba(248,250,252,0.25)';this.style.background='rgba(248,250,252,0.06)';this.style.boxShadow='0 0 14px rgba(248,250,252,0.08)'" onmouseout="this.style.color='#64748b';this.style.borderColor='rgba(255,255,255,0.06)';this.style.background='transparent';this.style.boxShadow='none'">● Referencias</div>
        </div>
    </div>

    <div class="obj-divider">🚨 DESAFÍO Y MATRIZ DE RIESGO</div>
    <div class="phase-row f-red">
        <div class="phase-label">PROBLEMA</div>
        <div class="phase-name">La mortalidad cardíaca es la <b>principal causa de muerte prevenible</b>. Los sistemas actuales son reactivos y no detectan la isquemia antes del colapso crítico.</div>
    </div>
    <div class="phase-row f-red">
        <div class="phase-label">RIESGOS DS</div>
        <div class="phase-name"><b>Desbalanceo Crítico:</b> Sesgo hacia la clase mayoritaria (sanos). <b>Drift de Datos:</b> Variabilidad en calibración de sensores ECG entre hospitales.</div>
    </div>
    <div class="phase-row f-red">
        <div class="phase-label">RIESGOS CLÍNICOS</div>
        <div class="phase-name"><b>Falsos Negativos:</b> El riesgo más alto; omitir un paciente crítico. <b>Sobrealerta:</b> Fatiga de alarmas si el modelo es hipersensible.</div>
    </div>

    <div class="obj-divider">🎯 ESTRATEGIA Y VALOR DE NEGOCIO</div>
    <div class="phase-row f-green">
        <div class="phase-label" style="font-size: 0.7em;">BUSINESS OBJ.</div>
        <div class="phase-name">Reducir la mortalidad hospitalaria en un <b>20%</b> y optimizar la rotación de camas UCI mediante altas tempranas seguras.</div>
    </div>
    <div class="phase-row f-green">
        <div class="phase-label" style="font-size: 0.7em;">Data Science OBJ.</div>
        <div class="phase-name">Desarrollar un clasificador multiclase para un <b>Early Warning Score (EWS)</b> auditable que estratifique el riesgo isquémico en tiempo real.</div>
    </div>

    <!-- EWS — AUDIT: umbrales numéricos agregados -->
    <div class="phase-row" style="background: rgba(255, 255, 255, 0.02); border-style: dotted; display: block;">
        <div class="phase-label" style="color: var(--cyan); font-size: 0.65em; margin-bottom: 20px; width: 100%;">ESTRATIFICACIÓN DE RIESGO (EWS)</div>
        <div class="phase-name">
            <div style="display: grid; grid-template-columns: 1.2fr 1fr; gap: 30px;">
                <div style="display: flex; flex-direction: column; gap: 12px;">
                    <div style="display: flex; align-items: center; gap: 15px;"><div class="dot-status dot-low"></div><span><b style="color:var(--green)">Bajo Riesgo</b> <span style="font-family:'JetBrains Mono',monospace;font-size:0.82em;opacity:0.6">(p &lt; 0.30)</span>: Monitoreo estándar.</span></div>
                    <div style="display: flex; align-items: center; gap: 15px;"><div class="dot-status dot-mid"></div><span><b style="color:var(--orange)">Riesgo Medio</b> <span style="font-family:'JetBrains Mono',monospace;font-size:0.82em;opacity:0.6">(0.30 – 0.65)</span>: Vigilancia intensiva.</span></div>
                    <div style="display: flex; align-items: center; gap: 15px;"><div class="dot-status dot-high"></div><span><b style="color:var(--red)">Alto Riesgo</b> <span style="font-family:'JetBrains Mono',monospace;font-size:0.82em;opacity:0.6">(p &gt; 0.65)</span>: Alerta inmediata UCI.</span></div>
                </div>
                <div style="font-size: 0.85em; opacity: 0.8; border-left: 1px solid rgba(255,255,255,0.1); padding-left: 20px; line-height: 1.8;">
                    <i style="color: var(--cyan);">Lógica:</i> El modelo asignará una <b>probabilidad ponderada</b>, permitiendo al clínico validar con biomarcadores. Alineado con KPI <b>Recall &gt; 80%</b>.
                </div>
            </div>
        </div>
    </div>

    <div class="phase-row f-green" style="display: block; padding-top: 20px;">
        <div class="phase-label" style="width: 100%; margin-bottom: 15px; color: var(--green);">CRITERIOS DE ÉXITO (KPIs)</div>
        <div style="display: grid; grid-template-columns: 1fr 1fr; gap: 20px; font-size: 0.9em; opacity: 0.9;">
            <div style="border-left: 2px solid var(--green); padding-left: 15px;"><b style="color: var(--green);">Métricas Técnicas:</b><br>• <b>Recall &gt; 80%</b> en Alto Riesgo.<br>• <b>AUC-ROC &gt; 0.85</b>.<br>• Error tipo II <b>&lt; 5%</b>.</div>
            <div style="border-left: 2px solid var(--green); padding-left: 15px;"><b style="color: var(--green);">Impacto de Negocio:</b><br>• <b>Reducción 20%</b> mortalidad.<br>• <b>Tasa Adopción &gt; 70%</b>.<br>• Ventana: <b>6-12h</b>.</div>
        </div>
    </div>

    <div class="obj-divider">👥 EQUIPO Y RECURSOS HUMANOS</div>
    <div class="team-grid">
        <div class="team-card"><div class="team-role">🔬 Lead Data Scientist</div><div class="team-desc">Diseño de modelo, ingeniería de features, validación estadística.</div></div>
        <div class="team-card"><div class="team-role">⚕️ Cardiólogo Clínico (SME)</div><div class="team-desc">Validación de criterios clínicos, interpretación de biomarcadores.</div></div>
        <div class="team-card"><div class="team-role">💾 Data Engineer</div><div class="team-desc">Pipeline ETL, integración HL7/FHIR, gestión de datos clínicos.</div></div>
        <div class="team-card"><div class="team-role">📊 Project Manager</div><div class="team-desc">Coordinación de sprints, gestión de stakeholders, reporting.</div></div>
    </div>

    <div class="obj-divider">📅 CRONOGRAMA DEL PROYECTO</div>
    <div class="timeline">
        <div class="timeline-item"><div class="timeline-week">SEMANA 1-2</div><div class="timeline-phase">Business Understanding</div><div class="timeline-desc">Definición de objetivos, stakeholders, análisis de riesgos.</div></div>
        <div class="timeline-item"><div class="timeline-week">SEMANA 3-6</div><div class="timeline-phase">Data Understanding & Prep</div><div class="timeline-desc">Exploración, limpieza, transformación, ingeniería de features.</div></div>
        <div class="timeline-item"><div class="timeline-week">SEMANA 7-10</div><div class="timeline-phase">Modeling & Evaluation</div><div class="timeline-desc">Entrenamiento, validación clínica, ajuste de hiperparámetros.</div></div>
        <div class="timeline-item"><div class="timeline-week">SEMANA 11-12</div><div class="timeline-phase">Deployment & Monitoring</div><div class="timeline-desc">Despliegue en producción, monitoreo de drift, documentación.</div></div>
    </div>



    <div class="obj-divider">🤝 ANÁLISIS DE STAKEHOLDERS</div>

    <div style="display:grid;grid-template-columns:1fr 1fr;gap:16px;">

        <!-- CARD: MÉDICOS -->
        <div style="border-radius:18px;border:1px solid rgba(0,242,254,0.2);background:rgba(0,242,254,0.03);padding:24px;transition:all 0.35s ease;cursor:default;" onmouseover="this.style.borderColor='rgba(0,242,254,0.6)';this.style.boxShadow='0 0 28px -4px rgba(0,242,254,0.25),inset 0 0 40px -25px rgba(0,242,254,0.1)'" onmouseout="this.style.borderColor='rgba(0,242,254,0.2)';this.style.boxShadow='none'">
            <div style="display:flex;align-items:center;gap:12px;margin-bottom:16px;">
                <span style="font-size:1.5em;">⚕️</span>
                <div>
                    <div style="font-family:'JetBrains Mono',monospace;font-size:0.9em;font-weight:800;color:#00f2fe;">Médicos</div>
                    <div style="font-size:0.72em;color:#475569;">Usuarios Finales</div>
                </div>
            </div>
            <div style="font-size:0.78em;color:#64748b;margin-bottom:6px;font-weight:600;">PREOCUPACIÓN CLAVE</div>
            <div style="font-size:0.82em;color:#94a3b8;margin-bottom:14px;line-height:1.5;">Precisión del modelo y utilidad real en el flujo de trabajo clínico diario.</div>
            <div style="font-size:0.78em;color:#64748b;margin-bottom:6px;font-weight:600;">CRITERIO DE ÉXITO</div>
            <div style="font-size:0.82em;color:#94a3b8;margin-bottom:18px;line-height:1.5;">Modelo útil en el flujo de trabajo sin aumentar carga operativa.</div>
            <div style="border-top:1px solid rgba(0,242,254,0.1);padding-top:16px;display:flex;flex-direction:column;gap:8px;">
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(0,242,254,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Reducción tiempo triage</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#00f2fe;">–40%</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(0,242,254,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Recall objetivo Alto Riesgo</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#00f2fe;">&gt;80%</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(0,242,254,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Ventana de detección temprana</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#00f2fe;">6–12h</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(0,242,254,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Latencia de inferencia</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#00f2fe;">&lt;200ms</span>
                </div>
            </div>
        </div>

        <!-- CARD: ADMIN HOSPITAL -->
        <div style="border-radius:18px;border:1px solid rgba(0,255,136,0.2);background:rgba(0,255,136,0.03);padding:24px;transition:all 0.35s ease;cursor:default;" onmouseover="this.style.borderColor='rgba(0,255,136,0.6)';this.style.boxShadow='0 0 28px -4px rgba(0,255,136,0.25),inset 0 0 40px -25px rgba(0,255,136,0.1)'" onmouseout="this.style.borderColor='rgba(0,255,136,0.2)';this.style.boxShadow='none'">
            <div style="display:flex;align-items:center;gap:12px;margin-bottom:16px;">
                <span style="font-size:1.5em;">🏥</span>
                <div>
                    <div style="font-family:'JetBrains Mono',monospace;font-size:0.9em;font-weight:800;color:#00ff88;">Admin. Hospital</div>
                    <div style="font-size:0.72em;color:#475569;">Sponsor</div>
                </div>
            </div>
            <div style="font-size:0.78em;color:#64748b;margin-bottom:6px;font-weight:600;">PREOCUPACIÓN CLAVE</div>
            <div style="font-size:0.82em;color:#94a3b8;margin-bottom:14px;line-height:1.5;">Costo-beneficio demostrable, eficiencia operativa y retorno de inversión.</div>
            <div style="font-size:0.78em;color:#64748b;margin-bottom:6px;font-weight:600;">CRITERIO DE ÉXITO</div>
            <div style="font-size:0.82em;color:#94a3b8;margin-bottom:18px;line-height:1.5;">ROI positivo en 12 meses y tasa de adopción &gt;70% del personal clínico.</div>
            <div style="border-top:1px solid rgba(0,255,136,0.1);padding-top:16px;display:flex;flex-direction:column;gap:8px;">
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(0,255,136,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Inversión total</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#00ff88;">$45K</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(0,255,136,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">ROI proyectado</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#00ff88;">320%</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(0,255,136,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Ahorro anual estimado</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#00ff88;">$8.2M</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(0,255,136,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Reducción mortalidad UCI</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#00ff88;">–20%</span>
                </div>
            </div>
            <div style="margin-top:10px;padding:10px 12px;background:rgba(0,255,136,0.04);border-radius:8px;border-left:2px solid rgba(0,255,136,0.2);font-size:0.67em;color:#475569;font-family:'JetBrains Mono',monospace;line-height:1.6;">
                <span style="color:#00ff88;">* Breakdown $45K:</span> $20K desarrollo · $15K infraestructura · $10K capacitación.<br>
                <span style="color:#00ff88;">* Metodología ROI:</span> UCI ~$1,200/día × –20% × 150 pac/año × 14 días = ~$504K/año. ×16 instituciones = <b style="color:#00ff88">$8.2M</b>.
            </div>
        </div>

        <!-- CARD: DEPTO TI -->
        <div style="border-radius:18px;border:1px solid rgba(139,92,246,0.2);background:rgba(139,92,246,0.03);padding:24px;transition:all 0.35s ease;cursor:default;" onmouseover="this.style.borderColor='rgba(139,92,246,0.6)';this.style.boxShadow='0 0 28px -4px rgba(139,92,246,0.25),inset 0 0 40px -25px rgba(139,92,246,0.1)'" onmouseout="this.style.borderColor='rgba(139,92,246,0.2)';this.style.boxShadow='none'">
            <div style="display:flex;align-items:center;gap:12px;margin-bottom:16px;">
                <span style="font-size:1.5em;">💾</span>
                <div>
                    <div style="font-family:'JetBrains Mono',monospace;font-size:0.9em;font-weight:800;color:#8b5cf6;">Depto. TI</div>
                    <div style="font-size:0.72em;color:#475569;">Infraestructura</div>
                </div>
            </div>
            <div style="font-size:0.78em;color:#64748b;margin-bottom:6px;font-weight:600;">PREOCUPACIÓN CLAVE</div>
            <div style="font-size:0.82em;color:#94a3b8;margin-bottom:14px;line-height:1.5;">Seguridad de datos, integración con EHR existente y cumplimiento normativo.</div>
            <div style="font-size:0.78em;color:#64748b;margin-bottom:6px;font-weight:600;">CRITERIO DE ÉXITO</div>
            <div style="font-size:0.82em;color:#94a3b8;margin-bottom:18px;line-height:1.5;">Cumplimiento total HIPAA y Ley 1581. Integración HL7/FHIR sin fricción operativa.</div>
            <div style="border-top:1px solid rgba(139,92,246,0.1);padding-top:16px;display:flex;flex-direction:column;gap:8px;">
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(139,92,246,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Presupuesto infraestructura</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#8b5cf6;">$15K</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(139,92,246,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Latencia máxima inferencia</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#8b5cf6;">&lt;200ms</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(139,92,246,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Estándar de integración</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#8b5cf6;">HL7/FHIR</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(139,92,246,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Multa incumplimiento HIPAA</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#8b5cf6;">&gt;$100K</span>
                </div>
            </div>
        </div>

        <!-- CARD: PACIENTES -->
        <div style="border-radius:18px;border:1px solid rgba(245,158,11,0.2);background:rgba(245,158,11,0.03);padding:24px;transition:all 0.35s ease;cursor:default;" onmouseover="this.style.borderColor='rgba(245,158,11,0.6)';this.style.boxShadow='0 0 28px -4px rgba(245,158,11,0.25),inset 0 0 40px -25px rgba(245,158,11,0.1)'" onmouseout="this.style.borderColor='rgba(245,158,11,0.2)';this.style.boxShadow='none'">
            <div style="display:flex;align-items:center;gap:12px;margin-bottom:16px;">
                <span style="font-size:1.5em;">🫀</span>
                <div>
                    <div style="font-family:'JetBrains Mono',monospace;font-size:0.9em;font-weight:800;color:#f59e0b;">Pacientes</div>
                    <div style="font-size:0.72em;color:#475569;">Beneficiarios</div>
                </div>
            </div>
            <div style="font-size:0.78em;color:#64748b;margin-bottom:6px;font-weight:600;">PREOCUPACIÓN CLAVE</div>
            <div style="font-size:0.82em;color:#94a3b8;margin-bottom:14px;line-height:1.5;">Privacidad de datos, calidad de atención y confianza en el diagnóstico asistido.</div>
            <div style="font-size:0.78em;color:#64748b;margin-bottom:6px;font-weight:600;">CRITERIO DE ÉXITO</div>
            <div style="font-size:0.82em;color:#94a3b8;margin-bottom:18px;line-height:1.5;">Mejora en diagnóstico temprano sin comprometer privacidad ni generar sobrediagnóstico.</div>
            <div style="border-top:1px solid rgba(245,158,11,0.1);padding-top:16px;display:flex;flex-direction:column;gap:8px;">
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(245,158,11,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Reducción mortalidad proyectada</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#f59e0b;">–20%</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(245,158,11,0.05);border-radius:8px;">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">Ventana de detección temprana</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.85em;font-weight:800;color:#f59e0b;">6–12h</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(255,68,68,0.07);border-radius:8px;border:1px solid rgba(255,68,68,0.12);">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">⚠ Costo Falso Negativo</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.75em;font-weight:700;color:#ff4444;">Vidas + demanda legal</span>
                </div>
                <div style="display:flex;justify-content:space-between;align-items:center;padding:8px 12px;background:rgba(245,158,11,0.07);border-radius:8px;border:1px solid rgba(245,158,11,0.12);">
                    <span style="font-size:0.75em;color:#64748b;font-family:'JetBrains Mono',monospace;">⚡ Costo Falso Positivo</span>
                    <span style="font-family:'JetBrains Mono',monospace;font-size:0.75em;font-weight:700;color:#f59e0b;">Ansiedad + recursos</span>
                </div>
            </div>
        </div>

    </div>
    <div class="obj-divider">⚠️ SUPUESTOS Y RESTRICCIONES</div>
    <div class="assumptions-list">
        <div class="assumption-item"><span class="assumption-icon">✓</span><div><b>Supuesto:</b> Los datos históricos son representativos de la población futura de pacientes.</div></div>
        <div class="assumption-item"><span class="assumption-icon">✓</span><div><b>Supuesto:</b> Expertos clínicos disponibles para validación semanal durante el desarrollo.</div></div>
        <div class="assumption-item"><span class="assumption-icon">✓</span><div><b>Supuesto:</b> La calidad del dataset Kaggle permite entrenar un modelo con validez clínica.</div></div>
        <div class="assumption-item"><span class="assumption-icon">⚡</span><div><b>Restricción:</b> Tiempo de inferencia del modelo debe ser &lt; 200ms para integración en tiempo real.</div></div>
        <div class="assumption-item"><span class="assumption-icon">⚡</span><div><b>Restricción:</b> Cumplimiento estricto de HIPAA y Ley 1581 (Colombia).</div></div>
        <div class="assumption-item"><span class="assumption-icon">⚡</span><div><b>Restricción:</b> El modelo debe ser explicable (no caja negra) para validación clínica.</div></div>
    </div>

    <div class="obj-divider">🔄 FLUJO DE TRABAJO CLÍNICO</div>
    <div class="workflow-steps">
        <div class="workflow-step"><div class="workflow-num">1</div><div class="workflow-text">Médico accede al sistema EHR</div></div>
        <div class="workflow-step"><div class="workflow-num">2</div><div class="workflow-text">Datos del paciente se importan</div></div>
        <div class="workflow-step"><div class="workflow-num">3</div><div class="workflow-text">Modelo ejecuta scoring EWS</div></div>
        <div class="workflow-step"><div class="workflow-num">4</div><div class="workflow-text">Alerta de riesgo se muestra</div></div>
    </div>

    <div class="obj-divider">🏗️ ARQUITECTURA Y RECURSOS</div>
    <div class="phase-row"><div class="phase-label">ESTRATEGIA</div><div class="phase-name">Modelado predictivo basado en <b>Machine Learning</b> con ingeniería de características sobre biomarcadores (Troponina) y ECG.</div></div>
    <div class="phase-row"><div class="phase-label">RECURSOS</div><div class="phase-name"><b>Stack:</b> Google Colab / Scikit-Learn / MLFlow. <b>Datos:</b> 1,000 registros clínicos bajo estándar <b>HL7/FHIR</b>.</div></div>

    <div class="obj-divider">⚖️ GOBERNANZA Y ÉTICA CLÍNICA</div>
    <div class="phase-row" style="opacity: 0.9; border-style: dashed;"><div class="phase-label">ÉTICA & SESGO</div><div class="phase-name">Monitoreo de <b>equidad algorítmica</b> para asegurar que el modelo no presente disparidades por género o edad.</div></div>
    <div class="phase-row" style="opacity: 0.9; border-style: dashed;"><div class="phase-label">PRIVACIDAD</div><div class="phase-name">Cumplimiento de <b>Ley 1581 (Colombia) y HIPAA</b>. Datos anonimizados mediante técnicas de enmascaramiento clínico.</div></div>


    <div class="obj-divider" style="letter-spacing: 4px; color: #444;">📙 Glosario Técnico</div>
    <div style="display:grid; grid-template-columns: 1fr 1fr; gap:30px; font-size:0.85em; opacity:0.7; padding:0 35px; font-weight:300; line-height:1.7;">
        <div>• <b>CDSS:</b> Clinical Decision Support System.<br>• <b>Drift:</b> Degradación del modelo en el tiempo.<br>• <b>Recall:</b> Sensibilidad para detectar positivos reales.<br>• <b>EWS:</b> Early Warning Score.</div>
        <div>• <b>KPI:</b> Key Performance Indicator.<br>• <b>HL7/FHIR:</b> Protocolos de intercambio de salud.<br>• <b>Isquemia:</b> Falta de riego sanguíneo al corazón.<br>• <b>ROI:</b> Return on Investment.</div>
    </div>

    <div class="obj-divider" style="letter-spacing: 4px; color: #444;">📚 Referencias y Evidencia Técnica</div>
    <div class="references-grid">
        <div><b>Soporte Técnico:</b><br>• <a href="{URL_CDSS}" target="_blank" class="ref-link">[CDSS Framework]</a><br>• <a href="{URL_Series}" target="_blank" class="ref-link">[Series Temporales IBM]</a><br>• <a href="{URL_hl7}" target="_blank" class="ref-link">[Estándar HL7/FHIR]</a></div>
        <div><b>Datos y Guías:</b><br>• <a href="{URL_DANE}" target="_blank" class="ref-link">[DANE - Mortalidad Colombia]</a><br>• <a href="{URL_KAGGLE}" target="_blank" class="ref-link">[Kaggle Dataset]</a><br>• <a href="{URL_ESC}" target="_blank" class="ref-link">[ESC Guidelines]</a></div>
    </div>
</div>
"""

# --- MÓDULO 5: SCRIPTS V.32 ---
f1_scripts = """
<script src="https://cdnjs.cloudflare.com/ajax/libs/gsap/3.12.2/gsap.min.js"></script>
<script>
    (function() {
        const init = function() {
            gsap.from("#main-f1-ui", { duration: 1.2, y: 30, opacity: 0, ease: "power3.out" });
            const container = document.body;
            for (let i = 0; i < 15; i++) {
                const particle = document.createElement('div');
                particle.className = 'particle';
                particle.style.left = Math.random() * 100 + '%';
                particle.style.top = Math.random() * 100 + '%';
                particle.style.animationDelay = Math.random() * 20 + 's';
                particle.style.opacity = Math.random() * 0.3 + 0.1;
                container.appendChild(particle);
            }
            /* FIX-3D V.31: sin mousemove rotationX/Y */
        };
        if (window.gsap) { init(); } else {
            const s = document.createElement('script');
            s.src = "https://cdnjs.cloudflare.com/ajax/libs/gsap/3.12.2/gsap.min.js";
            s.onload = init;
            document.head.appendChild(s);
        }
    })();
</script>
"""

# =============================================================================
# RENDERIZADO V.32
# =============================================================================
clear_output(wait=True)
try:
    display(HTML(f1_styles + f1_body + f1_scripts))
    print("✅ Fase 1 V.32: JetBrains Mono · EWS umbrales · ROI metodología · V.31 layout intacto")
except Exception as e:
    print(f"❌ Error: {e}")
# Out:
# <style>
#     @import url('https://fonts.googleapis.com/css2?family=JetBrains+Mono:wght@400;600;700;800&family=Inter:wght@300;400;600&display=swap');
#     :root { --cyan: #00f2fe; --red: #ff4444; --green: #00ff88; --kaggle: #20beff; --bg: #050a0f; --p-color: var(--cyan); --f2-violet: #8b5cf6; --arctic: #f8fafc; --orange: #f59e0b; --pink: #ff69b4; }
#     .master-container { font-family: 'Inter', sans-serif; max-width: 950px; margin: 40px auto; background: rgba(10, 20, 30, 0.75); backdrop-filter: blur(30px); border-radius: 35px; border: 1px solid rgba(255, 255, 255, 0.1); padding: 45px; color: white; box-shadow: 0 50px 100px rgba(0,0,0,0.8); position: relative; }
#     @property --angle { syntax: '<angle>'; initial-value: 0deg; inherits: false; }
#     @keyframes spin { from { --angle: 0deg; } to { --angle: 360deg; } }
# ...
