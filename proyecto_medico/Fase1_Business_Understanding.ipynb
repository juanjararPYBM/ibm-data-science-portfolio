# %%
# =============================================================================
# PROYECTO: PORTAFOLIO IBM DATA SCIENCE - FASE 1 (BUSINESS UNDERSTANDING)
# VERSIÓN: 25.3 (INTEGRIDAD TOTAL: GLOSARIO + REFERENCIAS VERBATIM)
# ESTADO: CAJA NEGRA FINALIZADA CON MOTOR TRINITY
# =============================================================================
from IPython.display import HTML, display

# --- MÓDULO 1: RUTAS ---
URL_AUTOR = "https://github.com"
URL_INDEX = "https://colab.research.google.com"

# --- MÓDULO 2: DISEÑO TRINITY (SYNC TOTAL) ---
f1_styles = f"""
<style>
    @import url('https://fonts.googleapis.com');

    :root {{ --cyan: #00f2fe; --red: #ff4444; --bg: #050a0f; --p-color: var(--cyan); }}

    .master-container {{
        font-family: 'Inter', sans-serif; max-width: 950px; margin: 40px auto;
        background: rgba(10, 20, 30, 0.75); backdrop-filter: blur(30px);
        border-radius: 35px; border: 1px solid rgba(255, 255, 255, 0.1);
        padding: 45px; color: white; transform-style: preserve-3d;
        box-shadow: 0 50px 100px rgba(0,0,0,0.8); position: relative; perspective: 1500px;
    }}

    .reveal-group {{ display: flex; gap: 12px; margin-bottom: 35px; position: relative; z-index: 10; }}
    .reveal-btn {{
        padding: 10px 18px !important; border-radius: 50px;
        background: rgba(255, 255, 255, 0.05); border: 1px solid rgba(255, 255, 255, 0.15);
        color: white !important; font-size: 0.75em; cursor: pointer;
        transition: all 0.6s cubic-bezier(0.165, 0.84, 0.44, 1);
        display: inline-flex; align-items: center; overflow: hidden;
        max-width: 110px; min-width: 110px; white-space: nowrap; font-weight: 600; text-decoration: none; position: relative;
    }}
    .reveal-btn:hover {{ max-width: 450px !important; background: rgba(255, 255, 255, 0.1) !important; transform: translateY(-3px) translateZ(20px); }}
    .reveal-btn strong {{ font-family: 'Orbitron'; color: var(--cyan); flex-shrink: 0; margin-right: 15px; }}
    .reveal-btn span {{ opacity: 0; transition: 0.4s; pointer-events: none; color: #ffffff !important; font-family: 'JetBrains Mono', monospace; }}
    .reveal-btn:hover span {{ opacity: 1; }}

    @property --angle {{ syntax: '<angle>'; initial-value: 0deg; inherits: false; }}
    @keyframes spin {{ from {{ --angle: 0deg; }} to {{ --angle: 360deg; }} }}
    .reveal-btn::before, .phase-row::before {{
        content: ''; position: absolute; inset: 0; padding: 2px; border-radius: inherit;
        background: conic-gradient(from var(--angle), transparent 75%, var(--p-color) 85%, var(--p-color) 95%, transparent 100%);
        -webkit-mask: linear-gradient(#fff 0 0) content-box, linear-gradient(#fff 0 0);
        mask: linear-gradient(#fff 0 0) content-box, linear-gradient(#fff 0 0);
        -webkit-mask-composite: xor; mask-composite: exclude; opacity: 0; transition: 0.3s;
    }}
    .reveal-btn:hover::before, .phase-row:hover::before {{ opacity: 1; animation: spin 1.5s linear infinite; }}

    .obj-divider {{
        display: flex; align-items: center; text-align: center; margin: 35px 0 25px 0;
        font-family: 'Orbitron'; font-size: 0.85em; letter-spacing: 6px; color: #555;
        font-weight: 900; transition: 0.5s; cursor: default;
    }}
    .obj-divider::before, .obj-divider::after {{ content: ''; flex: 1; border-bottom: 1px solid rgba(255,255,255,0.08); transition: 0.5s; }}
    .obj-divider::before {{ margin-right: 25px; }} .obj-divider::after {{ margin-left: 25px; }}
    .obj-divider:hover {{ color: var(--red) !important; text-shadow: 0 0 15px var(--red); letter-spacing: 10px; }}
    .obj-divider:hover::before, .obj-divider:hover::after {{ border-color: var(--red) !important; box-shadow: 0 0 10px var(--red); }}

    .phase-row {{
        position: relative; overflow: hidden; margin-bottom: 12px;
        background: rgba(255, 255, 255, 0.03); border: 1px solid rgba(255, 255, 255, 0.07);
        transition: all 0.4s cubic-bezier(0.165, 0.84, 0.44, 1); border-radius: 20px; padding: 25px 35px;
        display: flex; align-items: center; z-index: 2; --p-color: var(--cyan);
    }}
    .phase-row:hover {{ background: rgba(0, 242, 254, 0.05); transform: translateX(8px) translateZ(10px); }}
    .f-problema {{ --p-color: var(--red); background: rgba(255, 68, 68, 0.04) !important; border-color: rgba(255, 68, 68, 0.15) !important; }}
    .phase-label {{ font-family: 'Orbitron'; font-size: 0.8em; width: 135px; font-weight: 900; color: #666; flex-shrink: 0; transition: 0.4s; }}
    .phase-name {{ font-weight: 300; font-size: 1.02em; flex-grow: 1; opacity: 0.7; transition: 0.4s; line-height: 1.6; color: #eee; }}
    .phase-row:hover .phase-label {{ color: var(--p-color); }}
    .phase-row:hover .phase-name {{ opacity: 1; color: white; }}
</style>
"""

# --- MÓDULO 3: CONTENIDO VERBATIM (LITERAL) ---
f1_content = f"""
<div class="master-container" id="main-f1-ui">
    <div class="header-section">
        <h1 style="font-family:'Orbitron'; font-weight:900; font-size:2.4em; margin:0; line-height:1.2; color:var(--cyan)">Fase 1: Business Understanding</h1>
        <p style="color: #666; font-size: 1.05em; margin-bottom: 35px; font-weight: 600; letter-spacing: 0.5px;">Proyecto Final - IBM Data Science Professional Certificate</p>
        <div class="reveal-group">
            <a href="{URL_AUTOR}" target="_blank" class="reveal-btn"><strong>AUTOR</strong> <span>/ juanjararPYBM</span></a>
            <a href="{URL_INDEX}" target="_blank" class="reveal-btn"><strong>INDEX</strong> <span>/ Master Portfolio ↗</span></a>
        </div>
    </div>

    <div class="obj-divider">OBJETIVO</div>

    <div class="phase-row f-problema">
        <div class="phase-label">PROBLEMA</div>
        <div class="phase-name">La mortalidad cardíaca en hospitales colombianos es la <b>principal causa de muerte prevenible</b>. El sistema de salud actual carece de herramientas predictivas que identifiquen signos de isquemia antes del colapso, lo que imposibilita una intervención oportuna.</div>
    </div>

    <div class="phase-row">
        <div class="phase-label">ESTRATEGIA</div>
        <div class="phase-name">Ante la necesidad de una base sólida, utilizaremos un <b>DATASET DE REFERENCIA</b> de 1,000 pacientes de la India. Este conjunto permite modelar variables críticas como la depresión del <b>SEGMENTO ST</b> y niveles de troponina, factores universales para la validación de riesgos isquémicos.</div>
    </div>

    <div class="phase-row">
        <div class="phase-label">SUPERVIVENCIA</div>
        <div class="phase-name">Se busca una detección anticipada de <b>6 A 12 HORAS</b> para mejorar la supervivencia del paciente. El éxito se medirá por una reducción del 20% en mortalidad hospitalaria y una precisión que mantenga los falsos positivos bajo el 30%.</div>
    </div>

    <div class="phase-row">
        <div class="phase-label">REQUERIMIENTOS</div>
        <div class="phase-name">La implementación requiere una arquitectura de datos basada en estándares <b>HL7/FHIR</b> para garantizar que la información de monitores UCI y laboratorios fluya sin latencia hacia el modelo predictivo, cumpliendo con las guías médicas internacionales.</div>
    </div>

    <div class="obj-divider" style="letter-spacing: 4px; color: #444;">📙 Glosario Técnico y Clínico</div>
    <div style="display:grid; grid-template-columns: 1fr 1fr; gap:30px; font-size:0.85em; opacity:0.7; padding:0 35px; font-weight:300; line-height:1.7;">
        <div>
            • <b>Isquemia:</b> Falta de riego sanguíneo al corazón que causa daño miocárdico.<br>
            • <b>HL7/FHIR:</b> Protocolos globales para el intercambio de datos clínicos electrónicos.<br>
            • <b>Segmento ST:</b> Parte de un electrocardiograma que indica daño en el músculo cardiaco.
        </div>
        <div>
            • <b>KPI:</b> Indicador Clave de Desempeño (Key Performance Indicator).<br>
            • <b>Muerte Prevenible:</b> Decesos que pueden evitarse mediante diagnóstico y tratamiento rápido.<br>
            • <b>Troponina:</b> Biomarcador sanguíneo esencial para confirmar un infarto.
        </div>
    </div>

    <div class="obj-divider" style="letter-spacing: 4px; color: #444;">📚 Referencias Bibliográficas y Veracidad</div>
    <div style="font-size:0.82em; opacity:0.6; padding:0 35px; font-weight:300; line-height:1.6;">
        <b>Contexto Nacional:</b> DANE (2024). Estadísticas Vitales: Principales causas de defunción en el territorio nacional. [Respalda el Problema de Negocio].<br><br>
        <b>Modelo de Referencia:</b> Panday, A. (Kaggle). Cardiovascular Risk Data India (1,000 patients). [Respalda la Estrategia de Datos].<br><br>
        <b>Requerimientos Médicos:</b> ESC (2023). Guidelines for the management of acute coronary syndromes. [Respalda los Objetivos y Requerimientos Técnicos].
    </div>
</div>
"""

# --- MÓDULO 4: SCRIPTS (GSAP 3D) ---
f1_scripts = """
<script src="https://cdnjs.cloudflare.com"></script>
<script>
    (function() {
        const init = () => {
            gsap.from("#main-f1-ui", { duration: 1.5, y: 50, opacity: 0, ease: "power4.out" });
            const card = document.getElementById('main-f1-ui');
            document.addEventListener('mousemove', (e) => {
                if(!card) return;
                let x = (window.innerWidth / 2 - e.clientX) / 95;
                let y = (window.innerHeight / 2 - e.clientY) / 95;
                gsap.to(card, { duration: 0.8, rotationY: x, rotationX: -y, ease: "power2.out" });
            });
        };
        if (window.gsap) init();
    })();
</script>
"""

display(HTML(f1_styles + f1_content + f1_scripts))
# Out:
# <style>
#     @import url('https://fonts.googleapis.com');
#
#     :root { --cyan: #00f2fe; --red: #ff4444; --bg: #050a0f; --p-color: var(--cyan); }
#
#     .master-container {
#         font-family: 'Inter', sans-serif; max-width: 950px; margin: 40px auto;
#         background: rgba(10, 20, 30, 0.75); backdrop-filter: blur(30px);
#         border-radius: 35px; border: 1px solid rgba(255, 255, 255, 0.1);
#         padding: 45px; color: white; transform-style: preserve-3d;
#         box-shadow: 0 50px 100px rgba(0,0,0,0.8); position: relative; perspective: 1500px;
#     }
#
#     .reveal-group { display: flex; gap: 12px; margin-bottom: 35px; position: relative; z-index: 10; }
#     .reveal-btn {
#         padding: 10px 18px !important; border-radius: 50px;
#         background: rgba(255, 255, 255, 0.05); border: 1px solid rgba(255, 255, 255, 0.15);
#         color: white !important; font-size: 0.75em; cursor: pointer;
#         transition: all 0.6s cubic-bezier(0.165, 0.84, 0.44, 1);
# ...
