# %%
from IPython.display import HTML, display

# =============================================================================
# MÓDULO INTEGRAL: FASE 1 - BUSINESS UNDERSTANDING (V. FINAL PORTAFOLIO)
# =============================================================================

f1_final_fixed_html = """
<style>
    @import url('https://fonts.googleapis.com');

    :root {
        --f1-blue: #007bff;
        --f1-dark: #1a2a3a;
        --text-main: #34495e;
        --bg-light: #f8f9fa;
    }

    .f1-container {
        font-family: 'Inter', sans-serif;
        max-width: 850px;
        margin: auto;
        background: white;
        padding: 40px;
        border-radius: 20px;
        border: 1px solid #e1e4e8;
        box-shadow: 0 10px 30px rgba(0,0,0,0.02);
    }

    .f1-header { border-bottom: 2px solid var(--f1-blue); padding-bottom: 15px; margin-bottom: 30px; }
    .f1-header h1 { font-family: 'Montserrat', sans-serif; color: var(--f1-blue); font-size: 1.8em; margin: 0; }
    .f1-header p { font-size: 1em; color: #7f8c8d; margin-top: 5px; font-weight: 600; }

    .f1-section { margin-bottom: 20px; transition: transform 0.3s ease; }
    .f1-section:hover { transform: translateX(5px); }
    
    .f1-topic { 
        display: flex; align-items: flex-start; gap: 15px; 
        padding: 18px; border-radius: 12px; background: var(--bg-light);
        border-left: 4px solid var(--f1-blue);
    }
    
    .f1-icon { font-size: 1.5em; min-width: 40px; text-align: center; }
    .f1-content b { font-family: 'Montserrat', sans-serif; color: var(--f1-blue); display: block; margin-bottom: 6px; text-transform: uppercase; font-size: 0.82em; letter-spacing: 1px; }
    .f1-content p { margin: 0; font-size: 0.95em; color: var(--text-main); line-height: 1.6; }

    .f1-footer-box { 
        margin-top: 40px; padding: 25px; border-top: 1px solid #eee; 
        background: #fdfdfd; border-radius: 0 0 20px 20px; 
    }
    .f1-footer-title { font-family: 'Montserrat', sans-serif; font-size: 0.8em; text-transform: uppercase; color: #95a5a6; letter-spacing: 1px; margin-bottom: 15px; display: block; font-weight: 800; }
    
    .glosario-list { font-size: 0.85em; color: #5a6c7d; column-count: 2; gap: 30px; margin-bottom: 25px; }
    .biblio-item { font-size: 0.82em; color: #7f8c8d; margin-bottom: 12px; list-style: none; padding-left: 0; line-height: 1.4; border-bottom: 1px solid #f0f0f0; padding-bottom: 8px; }
    .ref-link { color: var(--f1-blue); text-decoration: none; font-weight: 600; }
</style>

<div class="f1-container">
    <div class="f1-header">
        <h1>Fase 1: Business Understanding</h1>
        <p>Proyecto Final - IBM Data Science Professional Certificate</p>
    </div>

    <!-- PROBLEMA DE NEGOCIO -->
    <div class="f1-section">
        <div class="f1-topic" style="background-color: #fff9f9; border-left-color: #dc3545;">
            <div class="f1-icon">🚨</div>
            <div class="f1-content">
                <b style="color: #dc3545;">Problema de Negocio</b>
                <p>La mortalidad cardíaca en hospitales colombianos es la <b>principal causa de muerte prevenible</b>. El sistema de salud actual carece de herramientas predictivas que identifiquen signos de isquemia antes del colapso, lo que imposibilita una intervención oportuna.</p>
            </div>
        </div>
    </div>

    <!-- ESTRATEGIA DE DATOS -->
    <div class="f1-section">
        <div class="f1-topic">
            <div class="f1-icon">🇮🇳</div>
            <div class="f1-content">
                <b>Modelo de Referencia Internacional</b>
                <p>Ante la necesidad de una base sólida, utilizaremos un <b>dataset de referencia</b> de 1,000 pacientes de la India. Este conjunto permite modelar variables críticas como la depresión del <b>segmento ST</b> y niveles de troponina, factores universales para la validación de riesgos isquémicos.</p>
            </div>
        </div>
    </div>

    <!-- OBJETIVOS CRISP-DM -->
    <div class="f1-section">
        <div class="f1-topic">
            <div class="f1-icon">🎯</div>
            <div class="f1-content">
                <b>Objetivo y KPIs de Supervivencia</b>
                <p>Se busca una detección anticipada de <b>6 a 12 horas</b> para mejorar la supervivencia del paciente. El éxito se medirá por una reducción del 20% en mortalidad hospitalaria y una precisión que mantenga los falsos positivos bajo el 30%.</p>
            </div>
        </div>
    </div>

    <!-- REQUERIMIENTOS TÉCNICOS -->
    <div class="f1-section">
        <div class="f1-topic">
            <div class="f1-icon">🛠️</div>
            <div class="f1-content">
                <b>Interoperabilidad y Requerimientos</b>
                <p>La implementación requiere una arquitectura de datos basada en estándares <b>HL7/FHIR</b> para garantizar que la información de monitores UCI y laboratorios fluya sin latencia hacia el modelo predictivo, cumpliendo con las guías médicas internacionales.</p>
            </div>
        </div>
    </div>

    <!-- GLOSARIO TÉCNICO -->
    <div class="f1-footer-box">
        <span class="f1-footer-title">📙 Glosario Técnico y Clínico</span>
        <div class="glosario-list">
            <div>• <b>Isquemia:</b> Falta de riego sanguíneo al corazón que causa daño miocárdico.</div>
            <div>• <b>HL7/FHIR:</b> Protocolos globales para el intercambio de datos clínicos electrónicos.</div>
            <div>• <b>Segmento ST:</b> Parte de un electrocardiograma que indica daño en el músculo cardiaco.</div>
            <div>• <b>KPI:</b> Indicador Clave de Desempeño (Key Performance Indicator).</div>
            <div>• <b>Muerte Prevenible:</b> Decesos que pueden evitarse mediante diagnóstico y tratamiento rápido.</div>
            <div>• <b>Troponina:</b> Biomarcador sanguíneo esencial para confirmar un infarto.</div>
        </div>

        <!-- REFERENCIAS BIBLIOGRÁFICAS -->
        <span class="f1-footer-title">📚 Referencias Bibliográficas y Veracidad</span>
        <ul style="padding: 0; margin: 0;">
            <li class="biblio-item">
                <b>Contexto Nacional:</b> <a href="https://www.dane.gov.co" class="ref-link">DANE (2024)</a>. Estadísticas Vitales: Principales causas de defunción en el territorio nacional. [Respalda el Problema de Negocio].
            </li>
            <li class="biblio-item">
                <b>Modelo de Referencia:</b> <a href="https://www.kaggle.com" class="ref-link">Panday, A. (Kaggle)</a>. Cardiovascular Risk Data India (1,000 patients). [Respalda la Estrategia de Datos].
            </li>
            <li class="biblio-item">
                <b>Requerimientos Médicos:</b> <a href="https://www.escardio.org" class="ref-link">ESC (2023)</a>. Guidelines for the management of acute coronary syndromes. [Respalda los Objetivos y Requerimientos Técnicos].
            </li>
        </ul>
    </div>
</div>
"""

display(HTML(f1_final_fixed_html))
# Out:
# <style>
#     @import url('https://fonts.googleapis.com');
#
#     :root {
#         --f1-blue: #007bff;
#         --f1-dark: #1a2a3a;
#         --text-main: #34495e;
#         --bg-light: #f8f9fa;
#     }
#
#     .f1-container {
#         font-family: 'Inter', sans-serif;
#         max-width: 850px;
#         margin: auto;
#         background: white;
#         padding: 40px;
#         border-radius: 20px;
#         border: 1px solid #e1e4e8;
#         box-shadow: 0 10px 30px rgba(0,0,0,0.02);
#     }
#
#     .f1-header { border-bottom: 2px solid var(--f1-blue); padding-bottom: 15px; margin-bottom: 30px; }
#     .f1-header h1 { font-family: 'Montserrat', sans-serif; color: var(--f1-blue); font-size: 1.8em; margin: 0; }
#     .f1-header p { font-size: 1em; color: #7f8c8d; margin-top: 5px; font-weight: 600; }
#
#     .f1-section { margin-bottom: 20px; transition: transform 0.3s ease; }
#     .f1-section:hover { transform: translateX(5px); }
#
#     .f1-topic {
# ...
